# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

import seaborn as sns

plt.style.use ( 'ggplot')
import nltk

# %%
# reading the data

df = pd.read_csv ('Reviews.csv')
print(df.shape)
df = df.head(100000)
print (df.shape)
# Out:
# (568454, 10)
# (100000, 10)

# %%
df.head()
# Out:
#    Id   ProductId          UserId                      ProfileName  \
# 0   1  B001E4KFG0  A3SGXH7AUHU8GW                       delmartian
# 1   2  B00813GRG4  A1D87F6ZCVE5NK                           dll pa
# 2   3  B000LQOCH0   ABXLMWJIXXAIN  Natalia Corres "Natalia Corres"
# 3   4  B000UA0QIQ  A395BORC6FGVXV                             Karl
# 4   5  B006K2ZZ7K  A1UQRSCLF8GW1T    Michael D. Bigham "M. Wassir"
#
#    HelpfulnessNumerator  HelpfulnessDenominator  Score        Time  \
# 0                     1                       1      5  1303862400
# 1                     0                       0      1  1346976000
# 2                     1                       1      4  1219017600
# 3                     3                       3      2  1307923200
# 4                     0                       0      5  1350777600
#
#                  Summary                                               Text
# 0  Good Quality Dog Food  I have bought several of the Vitality canned d...
# 1      Not as Advertised  Product arrived labeled as Jumbo Salted Peanut...
# 2  "Delight" says it all  This is a confection that has been around a fe...
# 3         Cough Medicine  If you are looking for the secret ingredient i...
# 4            Great taffy  Great taffy at a great price.  There was a wid...

# %%
##quick eda

ax = df['Score'].value_counts().sort_index() \
        .plot ( kind = "bar", title ="review vs stars", figsize =(10,5))
ax.set_xlabel('Review Stars')
plt.show()

# %% [markdown]
# # Basic NLTK

# %% [markdown]
# ## basic

# %%
example = df['Text'][50]
print ( example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.

# %%
tokens = nltk.word_tokenize(example)
tokens [:10]
# Out:
# ['This', 'oatmeal', 'is', 'not', 'good', '.', 'Its', 'mushy', ',', 'soft']

# %%
tagged = nltk.pos_tag(tokens)
tagged[:10]
# Out:
# [('This', 'DT'),
#  ('oatmeal', 'NN'),
#  ('is', 'VBZ'),
#  ('not', 'RB'),
#  ('good', 'JJ'),
#  ('.', '.'),
#  ('Its', 'PRP$'),
#  ('mushy', 'NN'),
#  (',', ','),
#  ('soft', 'JJ')]

# %%
entities = nltk.chunk.ne_chunk(tagged) 
entities.pprint()
# Out:
# (S
#   This/DT
#   oatmeal/NN
#   is/VBZ
#   not/RB
#   good/JJ
#   ./.
#   Its/PRP$
#   mushy/NN
#   ,/,
#   soft/JJ
#   ,/,
#   I/PRP
#   do/VBP
#   n't/RB
#   like/VB
#   it/PRP
#   ./.
#   (ORGANIZATION Quaker/NNP Oats/NNPS)
#   is/VBZ
#   the/DT
#   way/NN
#   to/TO
#   go/VB
#   ./.)

# %% [markdown]
# #vader

# %% [markdown]
# ## VADER Sentiment Scoring

# %%
from nltk.sentiment import SentimentIntensityAnalyzer
from tqdm.notebook import tqdm

sia = SentimentIntensityAnalyzer()

# %%
sia.polarity_scores('ok')
# Out:
# {'neg': 0.0, 'neu': 0.0, 'pos': 1.0, 'compound': 0.296}

# %%
sia.polarity_scores(example)
# Out:
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
#running the polarity scores on the entire data set

# res = {}

# for i, row in tqdm(df.iterrows(), total = len(df)):
    
#     text = row ['Text']
#     myid = row ['Id']
#     res[myid] = sia.polarity_scores(text)

res = {}
for i, row in tqdm(df.iterrows(), total=len(df)):
    text = row['Text']
    myid = row['Id']
    res[myid] = sia.polarity_scores(text)
# Out:
#   0%|          | 0/100000 [00:00<?, ?it/s]

# %%
vaders = pd.DataFrame(res).T
vaders =  vaders.reset_index().rename(columns = {'index' : 'Id'})
vaders = vaders.merge(df, how ='left')

# %%
# now we have the sentimental scores and metadat

vaders.head()
# Out:
#    Id    neg    neu    pos  compound   ProductId          UserId  \
# 0   1  0.000  0.695  0.305    0.9441  B001E4KFG0  A3SGXH7AUHU8GW
# 1   2  0.138  0.862  0.000   -0.5664  B00813GRG4  A1D87F6ZCVE5NK
# 2   3  0.091  0.754  0.155    0.8265  B000LQOCH0   ABXLMWJIXXAIN
# 3   4  0.000  1.000  0.000    0.0000  B000UA0QIQ  A395BORC6FGVXV
# 4   5  0.000  0.552  0.448    0.9468  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# #Plot VADER Results

# %%
ax = sns.barplot(data = vaders, x = 'Score', y = 'compound')
ax.set_title('Compound Score by Amazon Star Review')
# Out:
# Text(0.5, 1.0, 'Compound Score by Amazon Star Review')

# %%
fig, axs = plt.subplots( 1,3, figsize = (20,10))

sns.barplot(data =vaders, x ='Score', y = 'pos' , ax = axs[0])
sns.barplot(data =vaders, x ='Score', y = 'neu' , ax = axs[1])
sns.barplot(data =vaders, x ='Score', y = 'neg' , ax = axs[2])

axs[0].set_title('Positive')
axs[1].set_title('Neutral')
axs[2].set_title('Negative')
plt.tight_layout()
plt.show()

# %% [markdown]
# # Roberta Pretrained Model

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification
from scipy.special import softmax

# %%
MODEL = f"cardiffnlp/twitter-roberta-base-sentiment"
tokenizer = AutoTokenizer.from_pretrained(MODEL)
model = AutoModelForSequenceClassification.from_pretrained(MODEL)

# %%
# vader result on example

print (example)
sia.polarity_scores(example)
# Out:
# This oatmeal is not good. Its mushy, soft, I don't like it. Quaker Oats is the way to go.
# {'neg': 0.22, 'neu': 0.78, 'pos': 0.0, 'compound': -0.5448}

# %%
#for roberta

encoded_text = tokenizer(example, return_tensors ='pt')
output = model(**encoded_text)
print(output)
scores = output[0][0].detach().numpy()
print(scores)
scores =softmax(scores)
scores_dict = {
    'roberta_neg' : scores[0],
    'roberta_neu' : scores[1],
    'roberta_pos' : scores[2]
    
    
}

print(scores_dict)
# Out:
# SequenceClassifierOutput(loss=None, logits=tensor([[ 3.1436, -0.7107, -2.6559]], grad_fn=<AddmmBackward0>), hidden_states=None, attentions=None)
# [ 3.1436293 -0.7106685 -2.6558964]
# {'roberta_neg': 0.97635514, 'roberta_neu': 0.020687476, 'roberta_pos': 0.0029573706}

# %%
def polarity_scores_roberta(example):
    
    encoded_text = tokenizer(example, return_tensors ='pt')
    output = model(**encoded_text)
    scores = output[0][0].detach().numpy()
    scores =softmax(scores)
    scores_dict = {
        'roberta_neg' : scores[0],
        'roberta_neu' : scores[1],
        'roberta_pos' : scores[2]
    }
    return scores_dict

# %%
res = {}
df=df.head(500)


for i, row in tqdm(df.iterrows(), total = len(df)):
    try :
        
        text = row['Text']
        myid = row['Id']
        vader_result = sia.polarity_scores(text)
        vader_result_rename = {}
        for key, value in vader_result.items() :
            vader_result_rename[f"vader_{key}"] = value
        roberta_result = polarity_scores_roberta(text)
        both = {**vader_result_rename, **roberta_result}
        res[myid] = both
    except RuntimeError:
        print(f'Broke for id {myid}')
        res
# Out:
#   0%|          | 0/500 [00:00<?, ?it/s]
# Broke for id 83
# Broke for id 187

# %%
res
# Out:
# {1: {'vader_neg': 0.0,
#   'vader_neu': 0.695,
#   'vader_pos': 0.305,
#   'vader_compound': 0.9441,
#   'roberta_neg': 0.009624252,
#   'roberta_neu': 0.049980428,
#   'roberta_pos': 0.9403953},
#  2: {'vader_neg': 0.138,
#   'vader_neu': 0.862,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5664,
#   'roberta_neg': 0.5089861,
#   'roberta_neu': 0.45241353,
#   'roberta_pos': 0.038600344},
#  3: {'vader_neg': 0.091,
#   'vader_neu': 0.754,
#   'vader_pos': 0.155,
#   'vader_compound': 0.8265,
#   'roberta_neg': 0.0032288984,
#   'roberta_neu': 0.09806744,
#   'roberta_pos': 0.8987037},
#  4: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.0022951285,
#   'roberta_neu': 0.09021923,
#   'roberta_pos': 0.90748566},
#  5: {'vader_neg': 0.0,
#   'vader_neu': 0.552,
#   'vader_pos': 0.448,
#   'vader_compound': 0.9468,
#   'roberta_neg': 0.0016347291,
#   'roberta_neu': 0.01030247,
#   'roberta_pos': 0.98806286},
#  6: {'vader_neg': 0.029,
#   'vader_neu': 0.809,
#   'vader_pos': 0.163,
#   'vader_compound': 0.883,
#   'roberta_neg': 0.006129598,
#   'roberta_neu': 0.021795882,
#   'roberta_pos': 0.97207445},
#  7: {'vader_neg': 0.034,
#   'vader_neu': 0.693,
#   'vader_pos': 0.273,
#   'vader_compound': 0.9346,
#   'roberta_neg': 0.0013047527,
#   'roberta_neu': 0.007773787,
#   'roberta_pos': 0.99092144},
#  8: {'vader_neg': 0.0,
#   'vader_neu': 0.52,
#   'vader_pos': 0.48,
#   'vader_compound': 0.9487,
#   'roberta_neg': 0.0020293554,
#   'roberta_neu': 0.0056851967,
#   'roberta_pos': 0.9922855},
#  9: {'vader_neg': 0.0,
#   'vader_neu': 0.851,
#   'vader_pos': 0.149,
#   'vader_compound': 0.6369,
#   'roberta_neg': 0.0038735797,
#   'roberta_neu': 0.094156325,
#   'roberta_pos': 0.9019701},
#  10: {'vader_neg': 0.0,
#   'vader_neu': 0.705,
#   'vader_pos': 0.295,
#   'vader_compound': 0.8313,
#   'roberta_neg': 0.0031034567,
#   'roberta_neu': 0.05591218,
#   'roberta_pos': 0.9409843},
#  11: {'vader_neg': 0.017,
#   'vader_neu': 0.846,
#   'vader_pos': 0.137,
#   'vader_compound': 0.9746,
#   'roberta_neg': 0.019134127,
#   'roberta_neu': 0.0710445,
#   'roberta_pos': 0.9098214},
#  12: {'vader_neg': 0.113,
#   'vader_neu': 0.887,
#   'vader_pos': 0.0,
#   'vader_compound': -0.7579,
#   'roberta_neg': 0.3726434,
#   'roberta_neu': 0.5196989,
#   'roberta_pos': 0.10765764},
#  13: {'vader_neg': 0.031,
#   'vader_neu': 0.923,
#   'vader_pos': 0.046,
#   'vader_compound': 0.296,
#   'roberta_neg': 0.46612442,
#   'roberta_neu': 0.4152593,
#   'roberta_pos': 0.11861628},
#  14: {'vader_neg': 0.0,
#   'vader_neu': 0.355,
#   'vader_pos': 0.645,
#   'vader_compound': 0.9466,
#   'roberta_neg': 0.0014077479,
#   'roberta_neu': 0.0058832797,
#   'roberta_pos': 0.9927089},
#  15: {'vader_neg': 0.104,
#   'vader_neu': 0.632,
#   'vader_pos': 0.264,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.0018244252,
#   'roberta_neu': 0.02184099,
#   'roberta_pos': 0.9763346},
#  16: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.004562121,
#   'roberta_neu': 0.03232536,
#   'roberta_pos': 0.96311253},
#  17: {'vader_neg': 0.097,
#   'vader_neu': 0.694,
#   'vader_pos': 0.209,
#   'vader_compound': 0.7481,
#   'roberta_neg': 0.0029225894,
#   'roberta_neu': 0.013419523,
#   'roberta_pos': 0.9836579},
#  18: {'vader_neg': 0.0,
#   'vader_neu': 0.61,
#   'vader_pos': 0.39,
#   'vader_compound': 0.8883,
#   'roberta_neg': 0.0011118235,
#   'roberta_neu': 0.008006259,
#   'roberta_pos': 0.9908819},
#  19: {'vader_neg': 0.012,
#   'vader_neu': 0.885,
#   'vader_pos': 0.103,
#   'vader_compound': 0.8957,
#   'roberta_neg': 0.00303008,
#   'roberta_neu': 0.14215375,
#   'roberta_pos': 0.85481614},
#  20: {'vader_neg': 0.0,
#   'vader_neu': 0.863,
#   'vader_pos': 0.137,
#   'vader_compound': 0.6077,
#   'roberta_neg': 0.005554629,
#   'roberta_neu': 0.03246925,
#   'roberta_pos': 0.9619762},
#  21: {'vader_neg': 0.0,
#   'vader_neu': 0.865,
#   'vader_pos': 0.135,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.010422163,
#   'roberta_neu': 0.065259255,
#   'roberta_pos': 0.9243186},
#  22: {'vader_neg': 0.0,
#   'vader_neu': 0.739,
#   'vader_pos': 0.261,
#   'vader_compound': 0.9153,
#   'roberta_neg': 0.001678396,
#   'roberta_neu': 0.020744005,
#   'roberta_pos': 0.97757757},
#  23: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.7687,
#   'roberta_neg': 0.00947941,
#   'roberta_neu': 0.05693861,
#   'roberta_pos': 0.93358195},
#  24: {'vader_neg': 0.085,
#   'vader_neu': 0.771,
#   'vader_pos': 0.143,
#   'vader_compound': 0.2617,
#   'roberta_neg': 0.0032611806,
#   'roberta_neu': 0.023222994,
#   'roberta_pos': 0.97351587},
#  25: {'vader_neg': 0.038,
#   'vader_neu': 0.895,
#   'vader_pos': 0.068,
#   'vader_compound': 0.3939,
#   'roberta_neg': 0.44952756,
#   'roberta_neu': 0.3907345,
#   'roberta_pos': 0.15973787},
#  26: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.045314,
#   'roberta_neu': 0.7786214,
#   'roberta_pos': 0.17606467},
#  27: {'vader_neg': 0.128,
#   'vader_neu': 0.872,
#   'vader_pos': 0.0,
#   'vader_compound': -0.296,
#   'roberta_neg': 0.9533157,
#   'roberta_neu': 0.04058291,
#   'roberta_pos': 0.0061014},
#  28: {'vader_neg': 0.04,
#   'vader_neu': 0.808,
#   'vader_pos': 0.152,
#   'vader_compound': 0.5956,
#   'roberta_neg': 0.0038475813,
#   'roberta_neu': 0.02275416,
#   'roberta_pos': 0.97339827},
#  29: {'vader_neg': 0.022,
#   'vader_neu': 0.669,
#   'vader_pos': 0.309,
#   'vader_compound': 0.9913,
#   'roberta_neg': 0.0045323353,
#   'roberta_neu': 0.014126607,
#   'roberta_pos': 0.981341},
#  30: {'vader_neg': 0.017,
#   'vader_neu': 0.846,
#   'vader_pos': 0.137,
#   'vader_compound': 0.9746,
#   'roberta_neg': 0.019134127,
#   'roberta_neu': 0.0710445,
#   'roberta_pos': 0.9098214},
#  31: {'vader_neg': 0.041,
#   'vader_neu': 0.692,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9713,
#   'roberta_neg': 0.002430513,
#   'roberta_neu': 0.016508134,
#   'roberta_pos': 0.98106134},
#  32: {'vader_neg': 0.0,
#   'vader_neu': 0.484,
#   'vader_pos': 0.516,
#   'vader_compound': 0.9153,
#   'roberta_neg': 0.0013848746,
#   'roberta_neu': 0.009927845,
#   'roberta_pos': 0.9886873},
#  33: {'vader_neg': 0.069,
#   'vader_neu': 0.839,
#   'vader_pos': 0.092,
#   'vader_compound': 0.7103,
#   'roberta_neg': 0.11853336,
#   'roberta_neu': 0.3294422,
#   'roberta_pos': 0.5520245},
#  34: {'vader_neg': 0.024,
#   'vader_neu': 0.72,
#   'vader_pos': 0.256,
#   'vader_compound': 0.9779,
#   'roberta_neg': 0.0049691387,
#   'roberta_neu': 0.05102643,
#   'roberta_pos': 0.94400436},
#  35: {'vader_neg': 0.0,
#   'vader_neu': 0.874,
#   'vader_pos': 0.126,
#   'vader_compound': 0.9091,
#   'roberta_neg': 0.0021597596,
#   'roberta_neu': 0.01779365,
#   'roberta_pos': 0.98004663},
#  36: {'vader_neg': 0.024,
#   'vader_neu': 0.821,
#   'vader_pos': 0.155,
#   'vader_compound': 0.7622,
#   'roberta_neg': 0.0030508388,
#   'roberta_neu': 0.08110064,
#   'roberta_pos': 0.9158485},
#  37: {'vader_neg': 0.0,
#   'vader_neu': 0.754,
#   'vader_pos': 0.246,
#   'vader_compound': 0.9196,
#   'roberta_neg': 0.002434576,
#   'roberta_neu': 0.011576185,
#   'roberta_pos': 0.9859892},
#  38: {'vader_neg': 0.0,
#   'vader_neu': 0.938,
#   'vader_pos': 0.062,
#   'vader_compound': 0.4457,
#   'roberta_neg': 0.038969155,
#   'roberta_neu': 0.22200066,
#   'roberta_pos': 0.73903024},
#  39: {'vader_neg': 0.05,
#   'vader_neu': 0.846,
#   'vader_pos': 0.104,
#   'vader_compound': 0.7638,
#   'roberta_neg': 0.014056243,
#   'roberta_neu': 0.2988299,
#   'roberta_pos': 0.6871138},
#  40: {'vader_neg': 0.0,
#   'vader_neu': 0.856,
#   'vader_pos': 0.144,
#   'vader_compound': 0.8114,
#   'roberta_neg': 0.0012026617,
#   'roberta_neu': 0.02301091,
#   'roberta_pos': 0.97578645},
#  41: {'vader_neg': 0.033,
#   'vader_neu': 0.82,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9301,
#   'roberta_neg': 0.009690572,
#   'roberta_neu': 0.03783324,
#   'roberta_pos': 0.95247614},
#  42: {'vader_neg': 0.03,
#   'vader_neu': 0.848,
#   'vader_pos': 0.122,
#   'vader_compound': 0.9435,
#   'roberta_neg': 0.03651169,
#   'roberta_neu': 0.18096739,
#   'roberta_pos': 0.7825209},
#  43: {'vader_neg': 0.0,
#   'vader_neu': 0.588,
#   'vader_pos': 0.412,
#   'vader_compound': 0.9441,
#   'roberta_neg': 0.001403939,
#   'roberta_neu': 0.009315227,
#   'roberta_pos': 0.9892809},
#  44: {'vader_neg': 0.0,
#   'vader_neu': 0.685,
#   'vader_pos': 0.315,
#   'vader_compound': 0.9161,
#   'roberta_neg': 0.0019128784,
#   'roberta_neu': 0.016714513,
#   'roberta_pos': 0.9813726},
#  45: {'vader_neg': 0.031,
#   'vader_neu': 0.778,
#   'vader_pos': 0.191,
#   'vader_compound': 0.8421,
#   'roberta_neg': 0.005844248,
#   'roberta_neu': 0.041151866,
#   'roberta_pos': 0.9530039},
#  46: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.8868878,
#   'roberta_neu': 0.09925429,
#   'roberta_pos': 0.013857939},
#  47: {'vader_neg': 0.0,
#   'vader_neu': 0.737,
#   'vader_pos': 0.263,
#   'vader_compound': 0.9169,
#   'roberta_neg': 0.1003439,
#   'roberta_neu': 0.29550382,
#   'roberta_pos': 0.60415226},
#  48: {'vader_neg': 0.0,
#   'vader_neu': 0.868,
#   'vader_pos': 0.132,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.16032937,
#   'roberta_neu': 0.3389705,
#   'roberta_pos': 0.50070006},
#  49: {'vader_neg': 0.0,
#   'vader_neu': 0.821,
#   'vader_pos': 0.179,
#   'vader_compound': 0.747,
#   'roberta_neg': 0.0033884305,
#   'roberta_neu': 0.02127439,
#   'roberta_pos': 0.9753372},
#  50: {'vader_neg': 0.056,
#   'vader_neu': 0.865,
#   'vader_pos': 0.079,
#   'vader_compound': 0.2363,
#   'roberta_neg': 0.9021344,
#   'roberta_neu': 0.08792554,
#   'roberta_pos': 0.009940101},
#  51: {'vader_neg': 0.22,
#   'vader_neu': 0.78,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5448,
#   'roberta_neg': 0.97635514,
#   'roberta_neu': 0.020687476,
#   'roberta_pos': 0.0029573706},
#  52: {'vader_neg': 0.047,
#   'vader_neu': 0.735,
#   'vader_pos': 0.218,
#   'vader_compound': 0.9194,
#   'roberta_neg': 0.0047937287,
#   'roberta_neu': 0.026924009,
#   'roberta_pos': 0.9682823},
#  53: {'vader_neg': 0.09,
#   'vader_neu': 0.858,
#   'vader_pos': 0.052,
#   'vader_compound': -0.8259,
#   'roberta_neg': 0.52485424,
#   'roberta_neu': 0.37918487,
#   'roberta_pos': 0.09596092},
#  54: {'vader_neg': 0.075,
#   'vader_neu': 0.925,
#   'vader_pos': 0.0,
#   'vader_compound': -0.3612,
#   'roberta_neg': 0.42265758,
#   'roberta_neu': 0.5005049,
#   'roberta_pos': 0.076837584},
#  55: {'vader_neg': 0.0,
#   'vader_neu': 0.857,
#   'vader_pos': 0.143,
#   'vader_compound': 0.8761,
#   'roberta_neg': 0.0016398334,
#   'roberta_neu': 0.050242234,
#   'roberta_pos': 0.9481179},
#  56: {'vader_neg': 0.071,
#   'vader_neu': 0.708,
#   'vader_pos': 0.221,
#   'vader_compound': 0.8908,
#   'roberta_neg': 0.00180009,
#   'roberta_neu': 0.018932346,
#   'roberta_pos': 0.9792676},
#  57: {'vader_neg': 0.029,
#   'vader_neu': 0.694,
#   'vader_pos': 0.277,
#   'vader_compound': 0.908,
#   'roberta_neg': 0.0016082082,
#   'roberta_neu': 0.008115834,
#   'roberta_pos': 0.990276},
#  58: {'vader_neg': 0.0,
#   'vader_neu': 0.701,
#   'vader_pos': 0.299,
#   'vader_compound': 0.91,
#   'roberta_neg': 0.0020191846,
#   'roberta_neu': 0.018697951,
#   'roberta_pos': 0.9792829},
#  59: {'vader_neg': 0.0,
#   'vader_neu': 0.611,
#   'vader_pos': 0.389,
#   'vader_compound': 0.9323,
#   'roberta_neg': 0.0012205162,
#   'roberta_neu': 0.007787714,
#   'roberta_pos': 0.99099183},
#  60: {'vader_neg': 0.0,
#   'vader_neu': 0.638,
#   'vader_pos': 0.362,
#   'vader_compound': 0.8807,
#   'roberta_neg': 0.0038701734,
#   'roberta_neu': 0.08162689,
#   'roberta_pos': 0.9145029},
#  61: {'vader_neg': 0.0,
#   'vader_neu': 0.9,
#   'vader_pos': 0.1,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.0147165265,
#   'roberta_neu': 0.27715135,
#   'roberta_pos': 0.7081321},
#  62: {'vader_neg': 0.0,
#   'vader_neu': 0.741,
#   'vader_pos': 0.259,
#   'vader_compound': 0.8442,
#   'roberta_neg': 0.017847523,
#   'roberta_neu': 0.095916145,
#   'roberta_pos': 0.8862363},
#  63: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.9050873,
#   'roberta_neu': 0.08281486,
#   'roberta_pos': 0.012097818},
#  64: {'vader_neg': 0.055,
#   'vader_neu': 0.765,
#   'vader_pos': 0.179,
#   'vader_compound': 0.9817,
#   'roberta_neg': 0.013532349,
#   'roberta_neu': 0.070573285,
#   'roberta_pos': 0.9158944},
#  65: {'vader_neg': 0.046,
#   'vader_neu': 0.75,
#   'vader_pos': 0.205,
#   'vader_compound': 0.8674,
#   'roberta_neg': 0.0015688112,
#   'roberta_neu': 0.018417532,
#   'roberta_pos': 0.9800136},
#  66: {'vader_neg': 0.04,
#   'vader_neu': 0.822,
#   'vader_pos': 0.138,
#   'vader_compound': 0.5165,
#   'roberta_neg': 0.0031999776,
#   'roberta_neu': 0.08046344,
#   'roberta_pos': 0.9163366},
#  67: {'vader_neg': 0.057,
#   'vader_neu': 0.869,
#   'vader_pos': 0.073,
#   'vader_compound': 0.492,
#   'roberta_neg': 0.13516103,
#   'roberta_neu': 0.40439168,
#   'roberta_pos': 0.46044728},
#  68: {'vader_neg': 0.183,
#   'vader_neu': 0.776,
#   'vader_pos': 0.041,
#   'vader_compound': -0.9116,
#   'roberta_neg': 0.87971437,
#   'roberta_neu': 0.10624969,
#   'roberta_pos': 0.014035885},
#  69: {'vader_neg': 0.135,
#   'vader_neu': 0.71,
#   'vader_pos': 0.155,
#   'vader_compound': -0.0096,
#   'roberta_neg': 0.35050157,
#   'roberta_neu': 0.36837846,
#   'roberta_pos': 0.28111994},
#  70: {'vader_neg': 0.344,
#   'vader_neu': 0.52,
#   'vader_pos': 0.136,
#   'vader_compound': -0.7345,
#   'roberta_neg': 0.96015793,
#   'roberta_neu': 0.035429098,
#   'roberta_pos': 0.004412968},
#  71: {'vader_neg': 0.036,
#   'vader_neu': 0.916,
#   'vader_pos': 0.048,
#   'vader_compound': 0.2228,
#   'roberta_neg': 0.032239866,
#   'roberta_neu': 0.13916087,
#   'roberta_pos': 0.8285993},
#  72: {'vader_neg': 0.078,
#   'vader_neu': 0.701,
#   'vader_pos': 0.222,
#   'vader_compound': 0.9733,
#   'roberta_neg': 0.003874339,
#   'roberta_neu': 0.022212062,
#   'roberta_pos': 0.9739136},
#  73: {'vader_neg': 0.025,
#   'vader_neu': 0.653,
#   'vader_pos': 0.323,
#   'vader_compound': 0.9787,
#   'roberta_neg': 0.0013178965,
#   'roberta_neu': 0.010000757,
#   'roberta_pos': 0.9886813},
#  74: {'vader_neg': 0.093,
#   'vader_neu': 0.762,
#   'vader_pos': 0.144,
#   'vader_compound': 0.9665,
#   'roberta_neg': 0.54130054,
#   'roberta_neu': 0.3049055,
#   'roberta_pos': 0.15379395},
#  75: {'vader_neg': 0.0,
#   'vader_neu': 0.872,
#   'vader_pos': 0.128,
#   'vader_compound': 0.2263,
#   'roberta_neg': 0.13885984,
#   'roberta_neu': 0.5320563,
#   'roberta_pos': 0.3290839},
#  76: {'vader_neg': 0.106,
#   'vader_neu': 0.768,
#   'vader_pos': 0.126,
#   'vader_compound': 0.1098,
#   'roberta_neg': 0.9441382,
#   'roberta_neu': 0.05016807,
#   'roberta_pos': 0.0056936922},
#  77: {'vader_neg': 0.019,
#   'vader_neu': 0.898,
#   'vader_pos': 0.083,
#   'vader_compound': 0.5647,
#   'roberta_neg': 0.26665452,
#   'roberta_neu': 0.4316501,
#   'roberta_pos': 0.3016954},
#  78: {'vader_neg': 0.034,
#   'vader_neu': 0.798,
#   'vader_pos': 0.168,
#   'vader_compound': 0.8303,
#   'roberta_neg': 0.0035588224,
#   'roberta_neu': 0.02785454,
#   'roberta_pos': 0.9685866},
#  79: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.7814,
#   'roberta_neg': 0.0048486507,
#   'roberta_neu': 0.052556112,
#   'roberta_pos': 0.9425952},
#  80: {'vader_neg': 0.087,
#   'vader_neu': 0.589,
#   'vader_pos': 0.324,
#   'vader_compound': 0.8636,
#   'roberta_neg': 0.6261535,
#   'roberta_neu': 0.28211492,
#   'roberta_pos': 0.09173156},
#  81: {'vader_neg': 0.0,
#   'vader_neu': 0.723,
#   'vader_pos': 0.277,
#   'vader_compound': 0.9098,
#   'roberta_neg': 0.0015721094,
#   'roberta_neu': 0.0062695034,
#   'roberta_pos': 0.9921584},
#  82: {'vader_neg': 0.0,
#   'vader_neu': 0.663,
#   'vader_pos': 0.337,
#   'vader_compound': 0.9041,
#   'roberta_neg': 0.0025260614,
#   'roberta_neu': 0.012215318,
#   'roberta_pos': 0.9852586},
#  84: {'vader_neg': 0.055,
#   'vader_neu': 0.767,
#   'vader_pos': 0.178,
#   'vader_compound': 0.8642,
#   'roberta_neg': 0.10250654,
#   'roberta_neu': 0.4036049,
#   'roberta_pos': 0.4938886},
#  85: {'vader_neg': 0.109,
#   'vader_neu': 0.676,
#   'vader_pos': 0.214,
#   'vader_compound': 0.8431,
#   'roberta_neg': 0.12168548,
#   'roberta_neu': 0.35795143,
#   'roberta_pos': 0.5203631},
#  86: {'vader_neg': 0.035,
#   'vader_neu': 0.698,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9487,
#   'roberta_neg': 0.0024510382,
#   'roberta_neu': 0.0100348145,
#   'roberta_pos': 0.9875142},
#  87: {'vader_neg': 0.019,
#   'vader_neu': 0.855,
#   'vader_pos': 0.126,
#   'vader_compound': 0.8797,
#   'roberta_neg': 0.036023363,
#   'roberta_neu': 0.14819324,
#   'roberta_pos': 0.81578344},
#  88: {'vader_neg': 0.05,
#   'vader_neu': 0.735,
#   'vader_pos': 0.215,
#   'vader_compound': 0.7424,
#   'roberta_neg': 0.0051310062,
#   'roberta_neu': 0.040446788,
#   'roberta_pos': 0.95442224},
#  89: {'vader_neg': 0.048,
#   'vader_neu': 0.762,
#   'vader_pos': 0.19,
#   'vader_compound': 0.9716,
#   'roberta_neg': 0.016249029,
#   'roberta_neu': 0.10783338,
#   'roberta_pos': 0.8759176},
#  90: {'vader_neg': 0.029,
#   'vader_neu': 0.645,
#   'vader_pos': 0.326,
#   'vader_compound': 0.9554,
#   'roberta_neg': 0.003609499,
#   'roberta_neu': 0.009854284,
#   'roberta_pos': 0.9865362},
#  91: {'vader_neg': 0.0,
#   'vader_neu': 0.833,
#   'vader_pos': 0.167,
#   'vader_compound': 0.7351,
#   'roberta_neg': 0.009687852,
#   'roberta_neu': 0.13429171,
#   'roberta_pos': 0.8560204},
#  92: {'vader_neg': 0.0,
#   'vader_neu': 0.837,
#   'vader_pos': 0.163,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.007930279,
#   'roberta_neu': 0.04424152,
#   'roberta_pos': 0.9478282},
#  93: {'vader_neg': 0.069,
#   'vader_neu': 0.663,
#   'vader_pos': 0.268,
#   'vader_compound': 0.8255,
#   'roberta_neg': 0.002261892,
#   'roberta_neu': 0.0076761264,
#   'roberta_pos': 0.990062},
#  94: {'vader_neg': 0.01,
#   'vader_neu': 0.781,
#   'vader_pos': 0.208,
#   'vader_compound': 0.9882,
#   'roberta_neg': 0.008068776,
#   'roberta_neu': 0.05497634,
#   'roberta_pos': 0.9369549},
#  95: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.02168388,
#   'roberta_neu': 0.42294085,
#   'roberta_pos': 0.5553753},
#  96: {'vader_neg': 0.031,
#   'vader_neu': 0.732,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9273,
#   'roberta_neg': 0.0071166386,
#   'roberta_neu': 0.061204944,
#   'roberta_pos': 0.9316784},
#  97: {'vader_neg': 0.0,
#   'vader_neu': 0.818,
#   'vader_pos': 0.182,
#   'vader_compound': 0.982,
#   'roberta_neg': 0.0030773012,
#   'roberta_neu': 0.036150437,
#   'roberta_pos': 0.9607722},
#  98: {'vader_neg': 0.053,
#   'vader_neu': 0.793,
#   'vader_pos': 0.154,
#   'vader_compound': 0.7729,
#   'roberta_neg': 0.1561174,
#   'roberta_neu': 0.30707562,
#   'roberta_pos': 0.536807},
#  99: {'vader_neg': 0.024,
#   'vader_neu': 0.91,
#   'vader_pos': 0.066,
#   'vader_compound': 0.5106,
#   'roberta_neg': 0.092718825,
#   'roberta_neu': 0.5976609,
#   'roberta_pos': 0.30962023},
#  100: {'vader_neg': 0.173,
#   'vader_neu': 0.735,
#   'vader_pos': 0.092,
#   'vader_compound': -0.5267,
#   'roberta_neg': 0.9624426,
#   'roberta_neu': 0.031978734,
#   'roberta_pos': 0.0055787275},
#  101: {'vader_neg': 0.0,
#   'vader_neu': 0.807,
#   'vader_pos': 0.193,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.3069213,
#   'roberta_neu': 0.45656896,
#   'roberta_pos': 0.23650977},
#  102: {'vader_neg': 0.103,
#   'vader_neu': 0.752,
#   'vader_pos': 0.145,
#   'vader_compound': 0.2285,
#   'roberta_neg': 0.06290247,
#   'roberta_neu': 0.294516,
#   'roberta_pos': 0.6425816},
#  103: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9287,
#   'roberta_neg': 0.04052039,
#   'roberta_neu': 0.11086615,
#   'roberta_pos': 0.8486135},
#  104: {'vader_neg': 0.0,
#   'vader_neu': 0.859,
#   'vader_pos': 0.141,
#   'vader_compound': 0.7249,
#   'roberta_neg': 0.029932527,
#   'roberta_neu': 0.054880787,
#   'roberta_pos': 0.9151867},
#  105: {'vader_neg': 0.051,
#   'vader_neu': 0.577,
#   'vader_pos': 0.372,
#   'vader_compound': 0.9313,
#   'roberta_neg': 0.0038570915,
#   'roberta_neu': 0.013474408,
#   'roberta_pos': 0.9826685},
#  106: {'vader_neg': 0.0,
#   'vader_neu': 0.696,
#   'vader_pos': 0.304,
#   'vader_compound': 0.9603,
#   'roberta_neg': 0.0018723538,
#   'roberta_neu': 0.008443229,
#   'roberta_pos': 0.98968446},
#  107: {'vader_neg': 0.0,
#   'vader_neu': 0.791,
#   'vader_pos': 0.209,
#   'vader_compound': 0.5719,
#   'roberta_neg': 0.36725068,
#   'roberta_neu': 0.43870342,
#   'roberta_pos': 0.19404586},
#  108: {'vader_neg': 0.0,
#   'vader_neu': 0.804,
#   'vader_pos': 0.196,
#   'vader_compound': 0.9503,
#   'roberta_neg': 0.0019238489,
#   'roberta_neu': 0.016131043,
#   'roberta_pos': 0.98194516},
#  109: {'vader_neg': 0.059,
#   'vader_neu': 0.676,
#   'vader_pos': 0.265,
#   'vader_compound': 0.9116,
#   'roberta_neg': 0.0024852508,
#   'roberta_neu': 0.0058696126,
#   'roberta_pos': 0.99164516},
#  110: {'vader_neg': 0.014,
#   'vader_neu': 0.764,
#   'vader_pos': 0.222,
#   'vader_compound': 0.9841,
#   'roberta_neg': 0.0024270844,
#   'roberta_neu': 0.0118135195,
#   'roberta_pos': 0.9857594},
#  111: {'vader_neg': 0.059,
#   'vader_neu': 0.879,
#   'vader_pos': 0.062,
#   'vader_compound': 0.0176,
#   'roberta_neg': 0.071035676,
#   'roberta_neu': 0.4062137,
#   'roberta_pos': 0.5227506},
#  112: {'vader_neg': 0.0,
#   'vader_neu': 0.81,
#   'vader_pos': 0.19,
#   'vader_compound': 0.8769,
#   'roberta_neg': 0.003892135,
#   'roberta_neu': 0.021213956,
#   'roberta_pos': 0.97489387},
#  113: {'vader_neg': 0.037,
#   'vader_neu': 0.786,
#   'vader_pos': 0.177,
#   'vader_compound': 0.9946,
#   'roberta_neg': 0.11883127,
#   'roberta_neu': 0.38704342,
#   'roberta_pos': 0.49412525},
#  114: {'vader_neg': 0.0,
#   'vader_neu': 0.631,
#   'vader_pos': 0.369,
#   'vader_compound': 0.8779,
#   'roberta_neg': 0.0019037202,
#   'roberta_neu': 0.009111734,
#   'roberta_pos': 0.98898447},
#  115: {'vader_neg': 0.027,
#   'vader_neu': 0.727,
#   'vader_pos': 0.245,
#   'vader_compound': 0.9379,
#   'roberta_neg': 0.0037509762,
#   'roberta_neu': 0.0120698735,
#   'roberta_pos': 0.9841792},
#  116: {'vader_neg': 0.0,
#   'vader_neu': 0.645,
#   'vader_pos': 0.355,
#   'vader_compound': 0.872,
#   'roberta_neg': 0.001251192,
#   'roberta_neu': 0.01608139,
#   'roberta_pos': 0.9826674},
#  117: {'vader_neg': 0.0,
#   'vader_neu': 0.892,
#   'vader_pos': 0.108,
#   'vader_compound': 0.6573,
#   'roberta_neg': 0.003406014,
#   'roberta_neu': 0.039611995,
#   'roberta_pos': 0.95698196},
#  118: {'vader_neg': 0.0,
#   'vader_neu': 0.781,
#   'vader_pos': 0.219,
#   'vader_compound': 0.9751,
#   'roberta_neg': 0.0017548684,
#   'roberta_neu': 0.010143994,
#   'roberta_pos': 0.9881011},
#  119: {'vader_neg': 0.05,
#   'vader_neu': 0.872,
#   'vader_pos': 0.079,
#   'vader_compound': 0.8972,
#   'roberta_neg': 0.28056347,
#   'roberta_neu': 0.47737712,
#   'roberta_pos': 0.24205942},
#  120: {'vader_neg': 0.013,
#   'vader_neu': 0.785,
#   'vader_pos': 0.203,
#   'vader_compound': 0.9828,
#   'roberta_neg': 0.0032583813,
#   'roberta_neu': 0.018432537,
#   'roberta_pos': 0.9783091},
#  121: {'vader_neg': 0.026,
#   'vader_neu': 0.759,
#   'vader_pos': 0.215,
#   'vader_compound': 0.9509,
#   'roberta_neg': 0.0035531702,
#   'roberta_neu': 0.022995992,
#   'roberta_pos': 0.9734508},
#  122: {'vader_neg': 0.102,
#   'vader_neu': 0.822,
#   'vader_pos': 0.076,
#   'vader_compound': -0.3626,
#   'roberta_neg': 0.19982725,
#   'roberta_neu': 0.46116272,
#   'roberta_pos': 0.33901006},
#  123: {'vader_neg': 0.025,
#   'vader_neu': 0.803,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9022,
#   'roberta_neg': 0.1365534,
#   'roberta_neu': 0.34716147,
#   'roberta_pos': 0.5162851},
#  124: {'vader_neg': 0.017,
#   'vader_neu': 0.795,
#   'vader_pos': 0.188,
#   'vader_compound': 0.9769,
#   'roberta_neg': 0.084528,
#   'roberta_neu': 0.39469144,
#   'roberta_pos': 0.5207806},
#  125: {'vader_neg': 0.079,
#   'vader_neu': 0.67,
#   'vader_pos': 0.252,
#   'vader_compound': 0.9678,
#   'roberta_neg': 0.004302054,
#   'roberta_neu': 0.027235242,
#   'roberta_pos': 0.9684627},
#  126: {'vader_neg': 0.035,
#   'vader_neu': 0.87,
#   'vader_pos': 0.095,
#   'vader_compound': 0.5709,
#   'roberta_neg': 0.023989344,
#   'roberta_neu': 0.18277107,
#   'roberta_pos': 0.7932396},
#  127: {'vader_neg': 0.0,
#   'vader_neu': 0.721,
#   'vader_pos': 0.279,
#   'vader_compound': 0.9258,
#   'roberta_neg': 0.0015730266,
#   'roberta_neu': 0.014196356,
#   'roberta_pos': 0.9842306},
#  128: {'vader_neg': 0.067,
#   'vader_neu': 0.633,
#   'vader_pos': 0.299,
#   'vader_compound': 0.9022,
#   'roberta_neg': 0.007769847,
#   'roberta_neu': 0.049486924,
#   'roberta_pos': 0.9427432},
#  129: {'vader_neg': 0.043,
#   'vader_neu': 0.728,
#   'vader_pos': 0.229,
#   'vader_compound': 0.8142,
#   'roberta_neg': 0.002505719,
#   'roberta_neu': 0.013060362,
#   'roberta_pos': 0.98443395},
#  130: {'vader_neg': 0.114,
#   'vader_neu': 0.676,
#   'vader_pos': 0.21,
#   'vader_compound': 0.6721,
#   'roberta_neg': 0.58715993,
#   'roberta_neu': 0.2633001,
#   'roberta_pos': 0.14954004},
#  131: {'vader_neg': 0.0,
#   'vader_neu': 0.755,
#   'vader_pos': 0.245,
#   'vader_compound': 0.8658,
#   'roberta_neg': 0.001669051,
#   'roberta_neu': 0.016341789,
#   'roberta_pos': 0.98198915},
#  132: {'vader_neg': 0.135,
#   'vader_neu': 0.76,
#   'vader_pos': 0.105,
#   'vader_compound': -0.3612,
#   'roberta_neg': 0.74938285,
#   'roberta_neu': 0.2226979,
#   'roberta_pos': 0.027919294},
#  133: {'vader_neg': 0.046,
#   'vader_neu': 0.772,
#   'vader_pos': 0.181,
#   'vader_compound': 0.7902,
#   'roberta_neg': 0.08118543,
#   'roberta_neu': 0.193084,
#   'roberta_pos': 0.7257306},
#  134: {'vader_neg': 0.02,
#   'vader_neu': 0.878,
#   'vader_pos': 0.103,
#   'vader_compound': 0.8082,
#   'roberta_neg': 0.0017438813,
#   'roberta_neu': 0.013367537,
#   'roberta_pos': 0.98488855},
#  135: {'vader_neg': 0.0,
#   'vader_neu': 0.877,
#   'vader_pos': 0.123,
#   'vader_compound': 0.4215,
#   'roberta_neg': 0.0010293359,
#   'roberta_neu': 0.026390294,
#   'roberta_pos': 0.9725804},
#  136: {'vader_neg': 0.0,
#   'vader_neu': 0.9,
#   'vader_pos': 0.1,
#   'vader_compound': 0.6503,
#   'roberta_neg': 0.023649856,
#   'roberta_neu': 0.057855144,
#   'roberta_pos': 0.91849506},
#  137: {'vader_neg': 0.0,
#   'vader_neu': 0.695,
#   'vader_pos': 0.305,
#   'vader_compound': 0.9661,
#   'roberta_neg': 0.0014717451,
#   'roberta_neu': 0.011302724,
#   'roberta_pos': 0.9872255},
#  138: {'vader_neg': 0.0,
#   'vader_neu': 0.689,
#   'vader_pos': 0.311,
#   'vader_compound': 0.8591,
#   'roberta_neg': 0.02491214,
#   'roberta_neu': 0.10337328,
#   'roberta_pos': 0.8717146},
#  139: {'vader_neg': 0.15,
#   'vader_neu': 0.773,
#   'vader_pos': 0.077,
#   'vader_compound': -0.4199,
#   'roberta_neg': 0.1563997,
#   'roberta_neu': 0.24645066,
#   'roberta_pos': 0.5971496},
#  140: {'vader_neg': 0.043,
#   'vader_neu': 0.833,
#   'vader_pos': 0.125,
#   'vader_compound': 0.835,
#   'roberta_neg': 0.02440162,
#   'roberta_neu': 0.07160538,
#   'roberta_pos': 0.90399307},
#  141: {'vader_neg': 0.098,
#   'vader_neu': 0.787,
#   'vader_pos': 0.114,
#   'vader_compound': 0.2023,
#   'roberta_neg': 0.24081129,
#   'roberta_neu': 0.43190488,
#   'roberta_pos': 0.3272838},
#  142: {'vader_neg': 0.0,
#   'vader_neu': 0.782,
#   'vader_pos': 0.218,
#   'vader_compound': 0.7814,
#   'roberta_neg': 0.016400807,
#   'roberta_neu': 0.087009,
#   'roberta_pos': 0.8965902},
#  143: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9296,
#   'roberta_neg': 0.0025163004,
#   'roberta_neu': 0.00723264,
#   'roberta_pos': 0.99025106},
#  144: {'vader_neg': 0.059,
#   'vader_neu': 0.667,
#   'vader_pos': 0.274,
#   'vader_compound': 0.9653,
#   'roberta_neg': 0.0021510706,
#   'roberta_neu': 0.011133478,
#   'roberta_pos': 0.9867155},
#  145: {'vader_neg': 0.058,
#   'vader_neu': 0.841,
#   'vader_pos': 0.102,
#   'vader_compound': 0.6124,
#   'roberta_neg': 0.50522566,
#   'roberta_neu': 0.4370697,
#   'roberta_pos': 0.057704672},
#  146: {'vader_neg': 0.144,
#   'vader_neu': 0.677,
#   'vader_pos': 0.178,
#   'vader_compound': 0.6341,
#   'roberta_neg': 0.005146591,
#   'roberta_neu': 0.034386694,
#   'roberta_pos': 0.96046674},
#  147: {'vader_neg': 0.087,
#   'vader_neu': 0.783,
#   'vader_pos': 0.13,
#   'vader_compound': 0.7567,
#   'roberta_neg': 0.36342314,
#   'roberta_neu': 0.41858402,
#   'roberta_pos': 0.21799284},
#  148: {'vader_neg': 0.058,
#   'vader_neu': 0.867,
#   'vader_pos': 0.075,
#   'vader_compound': 0.1533,
#   'roberta_neg': 0.055790223,
#   'roberta_neu': 0.12982313,
#   'roberta_pos': 0.81438667},
#  149: {'vader_neg': 0.04,
#   'vader_neu': 0.833,
#   'vader_pos': 0.127,
#   'vader_compound': 0.6956,
#   'roberta_neg': 0.044037934,
#   'roberta_neu': 0.18290491,
#   'roberta_pos': 0.77305716},
#  150: {'vader_neg': 0.0,
#   'vader_neu': 0.709,
#   'vader_pos': 0.291,
#   'vader_compound': 0.9231,
#   'roberta_neg': 0.0012933485,
#   'roberta_neu': 0.013132103,
#   'roberta_pos': 0.9855745},
#  151: {'vader_neg': 0.0,
#   'vader_neu': 0.564,
#   'vader_pos': 0.436,
#   'vader_compound': 0.9858,
#   'roberta_neg': 0.001566443,
#   'roberta_neu': 0.006832089,
#   'roberta_pos': 0.9916014},
#  152: {'vader_neg': 0.0,
#   'vader_neu': 0.784,
#   'vader_pos': 0.216,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.0020130528,
#   'roberta_neu': 0.062400088,
#   'roberta_pos': 0.9355868},
#  153: {'vader_neg': 0.0,
#   'vader_neu': 0.775,
#   'vader_pos': 0.225,
#   'vader_compound': 0.7269,
#   'roberta_neg': 0.0013454008,
#   'roberta_neu': 0.027191417,
#   'roberta_pos': 0.9714632},
#  154: {'vader_neg': 0.12,
#   'vader_neu': 0.76,
#   'vader_pos': 0.12,
#   'vader_compound': 0.2502,
#   'roberta_neg': 0.70836943,
#   'roberta_neu': 0.23563297,
#   'roberta_pos': 0.055997584},
#  155: {'vader_neg': 0.0,
#   'vader_neu': 0.647,
#   'vader_pos': 0.353,
#   'vader_compound': 0.9803,
#   'roberta_neg': 0.0016300853,
#   'roberta_neu': 0.0053900634,
#   'roberta_pos': 0.9929798},
#  156: {'vader_neg': 0.0,
#   'vader_neu': 0.768,
#   'vader_pos': 0.232,
#   'vader_compound': 0.9681,
#   'roberta_neg': 0.0019890002,
#   'roberta_neu': 0.012380148,
#   'roberta_pos': 0.9856309},
#  157: {'vader_neg': 0.191,
#   'vader_neu': 0.809,
#   'vader_pos': 0.0,
#   'vader_compound': -0.7269,
#   'roberta_neg': 0.022001695,
#   'roberta_neu': 0.16944806,
#   'roberta_pos': 0.8085503},
#  158: {'vader_neg': 0.071,
#   'vader_neu': 0.514,
#   'vader_pos': 0.415,
#   'vader_compound': 0.8934,
#   'roberta_neg': 0.0023668169,
#   'roberta_neu': 0.028503519,
#   'roberta_pos': 0.9691297},
#  159: {'vader_neg': 0.065,
#   'vader_neu': 0.893,
#   'vader_pos': 0.042,
#   'vader_compound': -0.4721,
#   'roberta_neg': 0.12988521,
#   'roberta_neu': 0.32907444,
#   'roberta_pos': 0.54104036},
#  160: {'vader_neg': 0.081,
#   'vader_neu': 0.779,
#   'vader_pos': 0.14,
#   'vader_compound': 0.4194,
#   'roberta_neg': 0.08064918,
#   'roberta_neu': 0.27685276,
#   'roberta_pos': 0.642498},
#  161: {'vader_neg': 0.0,
#   'vader_neu': 0.644,
#   'vader_pos': 0.356,
#   'vader_compound': 0.9117,
#   'roberta_neg': 0.0012850066,
#   'roberta_neu': 0.010186672,
#   'roberta_pos': 0.9885283},
#  162: {'vader_neg': 0.106,
#   'vader_neu': 0.894,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5504,
#   'roberta_neg': 0.9152984,
#   'roberta_neu': 0.07865348,
#   'roberta_pos': 0.006048235},
#  163: {'vader_neg': 0.072,
#   'vader_neu': 0.652,
#   'vader_pos': 0.276,
#   'vader_compound': 0.9517,
#   'roberta_neg': 0.024918264,
#   'roberta_neu': 0.14422967,
#   'roberta_pos': 0.83085203},
#  164: {'vader_neg': 0.047,
#   'vader_neu': 0.869,
#   'vader_pos': 0.085,
#   'vader_compound': 0.4199,
#   'roberta_neg': 0.0043773213,
#   'roberta_neu': 0.051931,
#   'roberta_pos': 0.9436916},
#  165: {'vader_neg': 0.025,
#   'vader_neu': 0.752,
#   'vader_pos': 0.223,
#   'vader_compound': 0.8957,
#   'roberta_neg': 0.36830834,
#   'roberta_neu': 0.4251973,
#   'roberta_pos': 0.20649433},
#  166: {'vader_neg': 0.032,
#   'vader_neu': 0.717,
#   'vader_pos': 0.251,
#   'vader_compound': 0.9597,
#   'roberta_neg': 0.0017836947,
#   'roberta_neu': 0.017604066,
#   'roberta_pos': 0.9806122},
#  167: {'vader_neg': 0.0,
#   'vader_neu': 0.657,
#   'vader_pos': 0.343,
#   'vader_compound': 0.9098,
#   'roberta_neg': 0.0016492167,
#   'roberta_neu': 0.028126493,
#   'roberta_pos': 0.9702243},
#  168: {'vader_neg': 0.05,
#   'vader_neu': 0.905,
#   'vader_pos': 0.045,
#   'vader_compound': -0.1154,
#   'roberta_neg': 0.9482189,
#   'roberta_neu': 0.046903588,
#   'roberta_pos': 0.004877555},
#  169: {'vader_neg': 0.186,
#   'vader_neu': 0.74,
#   'vader_pos': 0.074,
#   'vader_compound': -0.5283,
#   'roberta_neg': 0.9343901,
#   'roberta_neu': 0.05704221,
#   'roberta_pos': 0.008567603},
#  170: {'vader_neg': 0.141,
#   'vader_neu': 0.832,
#   'vader_pos': 0.028,
#   'vader_compound': -0.7721,
#   'roberta_neg': 0.69411045,
#   'roberta_neu': 0.26396167,
#   'roberta_pos': 0.041927904},
#  171: {'vader_neg': 0.0,
#   'vader_neu': 0.854,
#   'vader_pos': 0.146,
#   'vader_compound': 0.6476,
#   'roberta_neg': 0.0017671374,
#   'roberta_neu': 0.057575557,
#   'roberta_pos': 0.9406573},
#  172: {'vader_neg': 0.04,
#   'vader_neu': 0.844,
#   'vader_pos': 0.116,
#   'vader_compound': 0.6808,
#   'roberta_neg': 0.005957366,
#   'roberta_neu': 0.048739374,
#   'roberta_pos': 0.94530326},
#  173: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.8906,
#   'roberta_neg': 0.0021157125,
#   'roberta_neu': 0.01113412,
#   'roberta_pos': 0.9867502},
#  174: {'vader_neg': 0.022,
#   'vader_neu': 0.788,
#   'vader_pos': 0.189,
#   'vader_compound': 0.9901,
#   'roberta_neg': 0.0049084467,
#   'roberta_neu': 0.048054643,
#   'roberta_pos': 0.9470369},
#  175: {'vader_neg': 0.04,
#   'vader_neu': 0.722,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9782,
#   'roberta_neg': 0.04203772,
#   'roberta_neu': 0.16823092,
#   'roberta_pos': 0.7897314},
#  176: {'vader_neg': 0.0,
#   'vader_neu': 0.874,
#   'vader_pos': 0.126,
#   'vader_compound': 0.7579,
#   'roberta_neg': 0.0014610904,
#   'roberta_neu': 0.01789802,
#   'roberta_pos': 0.9806409},
#  177: {'vader_neg': 0.0,
#   'vader_neu': 0.938,
#   'vader_pos': 0.062,
#   'vader_compound': 0.4215,
#   'roberta_neg': 0.0027336779,
#   'roberta_neu': 0.043978777,
#   'roberta_pos': 0.95328754},
#  178: {'vader_neg': 0.058,
#   'vader_neu': 0.794,
#   'vader_pos': 0.148,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.033187263,
#   'roberta_neu': 0.17210284,
#   'roberta_pos': 0.7947099},
#  179: {'vader_neg': 0.2,
#   'vader_neu': 0.63,
#   'vader_pos': 0.171,
#   'vader_compound': 0.1203,
#   'roberta_neg': 0.0625264,
#   'roberta_neu': 0.18336488,
#   'roberta_pos': 0.7541087},
#  180: {'vader_neg': 0.048,
#   'vader_neu': 0.829,
#   'vader_pos': 0.122,
#   'vader_compound': 0.7458,
#   'roberta_neg': 0.011383903,
#   'roberta_neu': 0.054276645,
#   'roberta_pos': 0.93433946},
#  181: {'vader_neg': 0.076,
#   'vader_neu': 0.767,
#   'vader_pos': 0.156,
#   'vader_compound': 0.6085,
#   'roberta_neg': 0.11886143,
#   'roberta_neu': 0.34905016,
#   'roberta_pos': 0.5320884},
#  182: {'vader_neg': 0.0,
#   'vader_neu': 0.433,
#   'vader_pos': 0.567,
#   'vader_compound': 0.9667,
#   'roberta_neg': 0.0018885667,
#   'roberta_neu': 0.007512769,
#   'roberta_pos': 0.9905986},
#  183: {'vader_neg': 0.088,
#   'vader_neu': 0.743,
#   'vader_pos': 0.169,
#   'vader_compound': 0.943,
#   'roberta_neg': 0.02521392,
#   'roberta_neu': 0.10751438,
#   'roberta_pos': 0.8672718},
#  184: {'vader_neg': 0.0,
#   'vader_neu': 0.857,
#   'vader_pos': 0.143,
#   'vader_compound': 0.9577,
#   'roberta_neg': 0.0025648703,
#   'roberta_neu': 0.03025901,
#   'roberta_pos': 0.96717614},
#  185: {'vader_neg': 0.11,
#   'vader_neu': 0.593,
#   'vader_pos': 0.297,
#   'vader_compound': 0.6597,
#   'roberta_neg': 0.0019503055,
#   'roberta_neu': 0.012991904,
#   'roberta_pos': 0.9850578},
#  186: {'vader_neg': 0.189,
#   'vader_neu': 0.811,
#   'vader_pos': 0.0,
#   'vader_compound': -0.5994,
#   'roberta_neg': 0.14508125,
#   'roberta_neu': 0.42684,
#   'roberta_pos': 0.42807874},
#  188: {'vader_neg': 0.0,
#   'vader_neu': 0.824,
#   'vader_pos': 0.176,
#   'vader_compound': 0.6983,
#   'roberta_neg': 0.037357394,
#   'roberta_neu': 0.22594155,
#   'roberta_pos': 0.736701},
#  189: {'vader_neg': 0.0,
#   'vader_neu': 0.843,
#   'vader_pos': 0.157,
#   'vader_compound': 0.8868,
#   'roberta_neg': 0.0033642177,
#   'roberta_neu': 0.030223,
#   'roberta_pos': 0.9664128},
#  190: {'vader_neg': 0.0,
#   'vader_neu': 0.934,
#   'vader_pos': 0.066,
#   'vader_compound': 0.3506,
#   'roberta_neg': 0.10829249,
#   'roberta_neu': 0.3163682,
#   'roberta_pos': 0.5753393},
#  191: {'vader_neg': 0.148,
#   'vader_neu': 0.64,
#   'vader_pos': 0.212,
#   'vader_compound': 0.4926,
#   'roberta_neg': 0.002107648,
#   'roberta_neu': 0.016815938,
#   'roberta_pos': 0.9810765},
#  192: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.9062,
#   'roberta_neg': 0.0013114836,
#   'roberta_neu': 0.012644123,
#   'roberta_pos': 0.9860444},
#  193: {'vader_neg': 0.055,
#   'vader_neu': 0.728,
#   'vader_pos': 0.217,
#   'vader_compound': 0.8756,
#   'roberta_neg': 0.030883651,
#   'roberta_neu': 0.05560902,
#   'roberta_pos': 0.91350734},
#  194: {'vader_neg': 0.031,
#   'vader_neu': 0.735,
#   'vader_pos': 0.234,
#   'vader_compound': 0.9595,
#   'roberta_neg': 0.007462425,
#   'roberta_neu': 0.026351789,
#   'roberta_pos': 0.9661858},
#  195: {'vader_neg': 0.082,
#   'vader_neu': 0.483,
#   'vader_pos': 0.435,
#   'vader_compound': 0.8299,
#   'roberta_neg': 0.04912082,
#   'roberta_neu': 0.20355533,
#   'roberta_pos': 0.7473239},
#  196: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9538,
#   'roberta_neg': 0.0020688805,
#   'roberta_neu': 0.02590665,
#   'roberta_pos': 0.97202444},
#  197: {'vader_neg': 0.0,
#   'vader_neu': 0.917,
#   'vader_pos': 0.083,
#   'vader_compound': 0.4738,
#   'roberta_neg': 0.06278974,
#   'roberta_neu': 0.30154246,
#   'roberta_pos': 0.6356678},
#  198: {'vader_neg': 0.0,
#   'vader_neu': 0.904,
#   'vader_pos': 0.096,
#   'vader_compound': 0.4153,
#   'roberta_neg': 0.64042616,
#   'roberta_neu': 0.31095314,
#   'roberta_pos': 0.048620693},
#  199: {'vader_neg': 0.0,
#   'vader_neu': 0.701,
#   'vader_pos': 0.299,
#   'vader_compound': 0.8268,
#   'roberta_neg': 0.0010561267,
#   'roberta_neu': 0.018172996,
#   'roberta_pos': 0.9807709},
#  200: {'vader_neg': 0.0,
#   'vader_neu': 0.811,
#   'vader_pos': 0.189,
#   'vader_compound': 0.7178,
#   'roberta_neg': 0.008402116,
#   'roberta_neu': 0.11609148,
#   'roberta_pos': 0.87550634},
#  201: {'vader_neg': 0.039,
#   'vader_neu': 0.888,
#   'vader_pos': 0.072,
#   'vader_compound': 0.6381,
#   'roberta_neg': 0.5752358,
#   'roberta_neu': 0.38917652,
#   'roberta_pos': 0.03558761},
#  202: {'vader_neg': 0.064,
#   'vader_neu': 0.597,
#   'vader_pos': 0.339,
#   'vader_compound': 0.9531,
#   'roberta_neg': 0.006313422,
#   'roberta_neu': 0.035880134,
#   'roberta_pos': 0.95780647},
#  203: {'vader_neg': 0.0,
#   'vader_neu': 0.688,
#   'vader_pos': 0.312,
#   'vader_compound': 0.8225,
#   'roberta_neg': 0.005034408,
#   'roberta_neu': 0.032026216,
#   'roberta_pos': 0.9629394},
#  204: {'vader_neg': 0.061,
#   'vader_neu': 0.814,
#   'vader_pos': 0.125,
#   'vader_compound': 0.8728,
#   'roberta_neg': 0.13175774,
#   'roberta_neu': 0.39078295,
#   'roberta_pos': 0.47745934},
#  205: {'vader_neg': 0.0,
#   'vader_neu': 0.882,
#   'vader_pos': 0.118,
#   'vader_compound': 0.6249,
#   'roberta_neg': 0.002167734,
#   'roberta_neu': 0.011405097,
#   'roberta_pos': 0.9864271},
#  206: {'vader_neg': 0.0,
#   'vader_neu': 0.754,
#   'vader_pos': 0.246,
#   'vader_compound': 0.9368,
#   'roberta_neg': 0.0017023436,
#   'roberta_neu': 0.0069474033,
#   'roberta_pos': 0.9913503},
#  207: {'vader_neg': 0.0,
#   'vader_neu': 0.59,
#   'vader_pos': 0.41,
#   'vader_compound': 0.8779,
#   'roberta_neg': 0.003047131,
#   'roberta_neu': 0.032365702,
#   'roberta_pos': 0.9645872},
#  208: {'vader_neg': 0.051,
#   'vader_neu': 0.8,
#   'vader_pos': 0.15,
#   'vader_compound': 0.8436,
#   'roberta_neg': 0.0048194123,
#   'roberta_neu': 0.046110854,
#   'roberta_pos': 0.94906974},
#  209: {'vader_neg': 0.05,
#   'vader_neu': 0.82,
#   'vader_pos': 0.13,
#   'vader_compound': 0.8913,
#   'roberta_neg': 0.09590453,
#   'roberta_neu': 0.28223965,
#   'roberta_pos': 0.62185585},
#  210: {'vader_neg': 0.045,
#   'vader_neu': 0.761,
#   'vader_pos': 0.194,
#   'vader_compound': 0.9893,
#   'roberta_neg': 0.013687982,
#   'roberta_neu': 0.116435006,
#   'roberta_pos': 0.869877},
#  211: {'vader_neg': 0.075,
#   'vader_neu': 0.755,
#   'vader_pos': 0.171,
#   'vader_compound': 0.9218,
#   'roberta_neg': 0.017106282,
#   'roberta_neu': 0.09481574,
#   'roberta_pos': 0.888078},
#  212: {'vader_neg': 0.051,
#   'vader_neu': 0.821,
#   'vader_pos': 0.129,
#   'vader_compound': 0.9529,
#   'roberta_neg': 0.022888873,
#   'roberta_neu': 0.23711179,
#   'roberta_pos': 0.73999935},
#  213: {'vader_neg': 0.051,
#   'vader_neu': 0.838,
#   'vader_pos': 0.11,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.69261533,
#   'roberta_neu': 0.2631964,
#   'roberta_pos': 0.044188306},
#  214: {'vader_neg': 0.095,
#   'vader_neu': 0.883,
#   'vader_pos': 0.022,
#   'vader_compound': -0.9726,
#   'roberta_neg': 0.76079756,
#   'roberta_neu': 0.21611898,
#   'roberta_pos': 0.023083434},
#  215: {'vader_neg': 0.0,
#   'vader_neu': 0.891,
#   'vader_pos': 0.109,
#   'vader_compound': 0.6476,
#   'roberta_neg': 0.0032443232,
#   'roberta_neu': 0.03989151,
#   'roberta_pos': 0.9568642},
#  216: {'vader_neg': 0.0,
#   'vader_neu': 0.798,
#   'vader_pos': 0.202,
#   'vader_compound': 0.7964,
#   'roberta_neg': 0.0017572829,
#   'roberta_neu': 0.015080395,
#   'roberta_pos': 0.9831623},
#  217: {'vader_neg': 0.078,
#   'vader_neu': 0.922,
#   'vader_pos': 0.0,
#   'vader_compound': -0.296,
#   'roberta_neg': 0.3688261,
#   'roberta_neu': 0.5396826,
#   'roberta_pos': 0.091491275},
#  218: {'vader_neg': 0.015,
#   'vader_neu': 0.884,
#   'vader_pos': 0.101,
#   'vader_compound': 0.9736,
#   'roberta_neg': 0.06660527,
#   'roberta_neu': 0.4823082,
#   'roberta_pos': 0.4510865},
#  219: {'vader_neg': 0.059,
#   'vader_neu': 0.774,
#   'vader_pos': 0.167,
#   'vader_compound': 0.9424,
#   'roberta_neg': 0.0041107587,
#   'roberta_neu': 0.03993765,
#   'roberta_pos': 0.9559516},
#  220: {'vader_neg': 0.031,
#   'vader_neu': 0.702,
#   'vader_pos': 0.267,
#   'vader_compound': 0.9812,
#   'roberta_neg': 0.005086321,
#   'roberta_neu': 0.03378196,
#   'roberta_pos': 0.96113175},
#  221: {'vader_neg': 0.027,
#   'vader_neu': 0.909,
#   'vader_pos': 0.064,
#   'vader_compound': 0.25,
#   'roberta_neg': 0.073030986,
#   'roberta_neu': 0.41860482,
#   'roberta_pos': 0.5083642},
#  222: {'vader_neg': 0.068,
#   'vader_neu': 0.666,
#   'vader_pos': 0.266,
#   'vader_compound': 0.9883,
#   'roberta_neg': 0.0041134465,
#   'roberta_neu': 0.06320599,
#   'roberta_pos': 0.93268055},
#  223: {'vader_neg': 0.0,
#   'vader_neu': 0.779,
#   'vader_pos': 0.221,
#   'vader_compound': 0.9623,
#   'roberta_neg': 0.0014788264,
#   'roberta_neu': 0.011571907,
#   'roberta_pos': 0.98694927},
#  224: {'vader_neg': 0.0,
#   'vader_neu': 0.607,
#   'vader_pos': 0.393,
#   'vader_compound': 0.923,
#   'roberta_neg': 0.0012665299,
#   'roberta_neu': 0.006620143,
#   'roberta_pos': 0.99211335},
#  225: {'vader_neg': 0.152,
#   'vader_neu': 0.739,
#   'vader_pos': 0.109,
#   'vader_compound': -0.25,
#   'roberta_neg': 0.90037614,
#   'roberta_neu': 0.09091956,
#   'roberta_pos': 0.008704323},
#  226: {'vader_neg': 0.064,
#   'vader_neu': 0.794,
#   'vader_pos': 0.141,
#   'vader_compound': 0.7951,
#   'roberta_neg': 0.057143442,
#   'roberta_neu': 0.15867653,
#   'roberta_pos': 0.7841801},
#  227: {'vader_neg': 0.139,
#   'vader_neu': 0.754,
#   'vader_pos': 0.108,
#   'vader_compound': -0.3774,
#   'roberta_neg': 0.010173992,
#   'roberta_neu': 0.07105034,
#   'roberta_pos': 0.9187756},
#  228: {'vader_neg': 0.106,
#   'vader_neu': 0.718,
#   'vader_pos': 0.176,
#   'vader_compound': 0.5475,
#   'roberta_neg': 0.003924316,
#   'roberta_neu': 0.06404408,
#   'roberta_pos': 0.93203163},
#  229: {'vader_neg': 0.0,
#   'vader_neu': 0.837,
#   'vader_pos': 0.163,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.38766915,
#   'roberta_neu': 0.49949256,
#   'roberta_pos': 0.112838365},
#  230: {'vader_neg': 0.025,
#   'vader_neu': 0.854,
#   'vader_pos': 0.121,
#   'vader_compound': 0.6478,
#   'roberta_neg': 0.867932,
#   'roberta_neu': 0.11575109,
#   'roberta_pos': 0.016316896},
#  231: {'vader_neg': 0.03,
#   'vader_neu': 0.726,
#   'vader_pos': 0.244,
#   'vader_compound': 0.9281,
#   'roberta_neg': 0.0012672328,
#   'roberta_neu': 0.01507466,
#   'roberta_pos': 0.98365813},
#  232: {'vader_neg': 0.0,
#   'vader_neu': 0.904,
#   'vader_pos': 0.096,
#   'vader_compound': 0.8144,
#   'roberta_neg': 0.0010959042,
#   'roberta_neu': 0.032064803,
#   'roberta_pos': 0.9668393},
#  233: {'vader_neg': 0.0,
#   'vader_neu': 0.807,
#   'vader_pos': 0.193,
#   'vader_compound': 0.8126,
#   'roberta_neg': 0.0026803531,
#   'roberta_neu': 0.018354528,
#   'roberta_pos': 0.9789651},
#  234: {'vader_neg': 0.103,
#   'vader_neu': 0.729,
#   'vader_pos': 0.169,
#   'vader_compound': 0.2481,
#   'roberta_neg': 0.9334733,
#   'roberta_neu': 0.059465088,
#   'roberta_pos': 0.007061634},
#  235: {'vader_neg': 0.0,
#   'vader_neu': 0.805,
#   'vader_pos': 0.195,
#   'vader_compound': 0.8655,
#   'roberta_neg': 0.0013840138,
#   'roberta_neu': 0.008378325,
#   'roberta_pos': 0.99023765},
#  236: {'vader_neg': 0.11,
#   'vader_neu': 0.792,
#   'vader_pos': 0.098,
#   'vader_compound': -0.4786,
#   'roberta_neg': 0.87115115,
#   'roberta_neu': 0.10877402,
#   'roberta_pos': 0.0200748},
#  237: {'vader_neg': 0.041,
#   'vader_neu': 0.793,
#   'vader_pos': 0.166,
#   'vader_compound': 0.9387,
#   'roberta_neg': 0.002203513,
#   'roberta_neu': 0.016126266,
#   'roberta_pos': 0.98167026},
#  238: {'vader_neg': 0.029,
#   'vader_neu': 0.798,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9936,
#   'roberta_neg': 0.14144766,
#   'roberta_neu': 0.3613945,
#   'roberta_pos': 0.49715784},
#  239: {'vader_neg': 0.064,
#   'vader_neu': 0.7,
#   'vader_pos': 0.236,
#   'vader_compound': 0.9677,
#   'roberta_neg': 0.002238803,
#   'roberta_neu': 0.010961042,
#   'roberta_pos': 0.9868002},
#  240: {'vader_neg': 0.0,
#   'vader_neu': 0.72,
#   'vader_pos': 0.28,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.0056281867,
#   'roberta_neu': 0.056015864,
#   'roberta_pos': 0.938356},
#  241: {'vader_neg': 0.066,
#   'vader_neu': 0.71,
#   'vader_pos': 0.223,
#   'vader_compound': 0.9553,
#   'roberta_neg': 0.015070679,
#   'roberta_neu': 0.06331336,
#   'roberta_pos': 0.9216159},
#  242: {'vader_neg': 0.0,
#   'vader_neu': 0.765,
#   'vader_pos': 0.235,
#   'vader_compound': 0.807,
#   'roberta_neg': 0.0037303348,
#   'roberta_neu': 0.025477454,
#   'roberta_pos': 0.97079223},
#  243: {'vader_neg': 0.0,
#   'vader_neu': 0.76,
#   'vader_pos': 0.24,
#   'vader_compound': 0.9344,
#   'roberta_neg': 0.00093678397,
#   'roberta_neu': 0.013776072,
#   'roberta_pos': 0.9852872},
#  244: {'vader_neg': 0.0,
#   'vader_neu': 1.0,
#   'vader_pos': 0.0,
#   'vader_compound': 0.0,
#   'roberta_neg': 0.20171827,
#   'roberta_neu': 0.6541579,
#   'roberta_pos': 0.14412384},
#  245: {'vader_neg': 0.081,
#   'vader_neu': 0.63,
#   'vader_pos': 0.289,
#   'vader_compound': 0.765,
#   'roberta_neg': 0.0013204154,
#   'roberta_neu': 0.02792964,
#   'roberta_pos': 0.9707499},
#  246: {'vader_neg': 0.072,
#   'vader_neu': 0.825,
#   'vader_pos': 0.103,
#   'vader_compound': 0.682,
#   'roberta_neg': 0.63435173,
#   'roberta_neu': 0.29252598,
#   'roberta_pos': 0.073122315},
#  247: {'vader_neg': 0.075,
#   'vader_neu': 0.633,
#   'vader_pos': 0.292,
#   'vader_compound': 0.9757,
#   'roberta_neg': 0.009014607,
#   'roberta_neu': 0.020562671,
#   'roberta_pos': 0.97042274},
#  248: {'vader_neg': 0.0,
#   'vader_neu': 0.869,
#   'vader_pos': 0.131,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.004992847,
#   'roberta_neu': 0.06529997,
#   'roberta_pos': 0.9297071},
#  249: {'vader_neg': 0.0,
#   'vader_neu': 0.602,
#   'vader_pos': 0.398,
#   'vader_compound': 0.9351,
#   'roberta_neg': 0.004430407,
#   'roberta_neu': 0.04089046,
#   'roberta_pos': 0.95467913},
#  250: {'vader_neg': 0.0,
#   'vader_neu': 0.75,
#   'vader_pos': 0.25,
#   'vader_compound': 0.7184,
#   'roberta_neg': 0.036980383,
#   'roberta_neu': 0.5882385,
#   'roberta_pos': 0.37478107},
#  251: {'vader_neg': 0.047,
#   'vader_neu': 0.781,
#   'vader_pos': 0.172,
#   'vader_compound': 0.9476,
#   'roberta_neg': 0.0018104177,
#   'roberta_neu': 0.012259974,
#   'roberta_pos': 0.98592967},
#  252: {'vader_neg': 0.076,
#   'vader_neu': 0.924,
#   'vader_pos': 0.0,
#   'vader_compound': -0.4823,
#   'roberta_neg': 0.19499962,
#   'roberta_neu': 0.41602764,
#   'roberta_pos': 0.38897282},
#  253: {'vader_neg': 0.107,
#   'vader_neu': 0.893,
#   'vader_pos': 0.0,
#   'vader_compound': -0.4767,
#   'roberta_neg': 0.9688306,
#   'roberta_neu': 0.02815438,
#   'roberta_pos': 0.0030151105},
#  254: {'vader_neg': 0.0,
#   'vader_neu': 0.801,
#   'vader_pos': 0.199,
#   'vader_compound': 0.9698,
#   'roberta_neg': 0.022160701,
#   'roberta_neu': 0.22714947,
#   'roberta_pos': 0.7506898},
#  255: {'vader_neg': 0.091,
#   'vader_neu': 0.736,
#   'vader_pos': 0.172,
#   'vader_compound': 0.4118,
#   'roberta_neg': 0.059614148,
#   'roberta_neu': 0.3147491,
#   'roberta_pos': 0.62563676},
#  256: {'vader_neg': 0.103,
#   'vader_neu': 0.699,
#   'vader_pos': 0.198,
#   'vader_compound': 0.9805,
#   'roberta_neg': 0.39860222,
#   'roberta_neu': 0.42504498,
#   'roberta_pos': 0.17635278},
#  257: {'vader_neg': 0.034,
#   'vader_neu': 0.664,
#   'vader_pos': 0.302,
#   'vader_compound': 0.9463,
#   'roberta_neg': 0.0016951454,
#   'roberta_neu': 0.008922466,
#   'roberta_pos': 0.9893824},
#  258: {'vader_neg': 0.105,
#   'vader_neu': 0.816,
#   'vader_pos': 0.079,
#   'vader_compound': -0.3489,
#   'roberta_neg': 0.97898453,
#   'roberta_neu': 0.018780319,
#   'roberta_pos': 0.0022350622},
#  259: {'vader_neg': 0.04,
#   'vader_neu': 0.841,
#   'vader_pos': 0.119,
#   'vader_compound': 0.8883,
#   'roberta_neg': 0.10289293,
#   'roberta_neu': 0.28166297,
#   'roberta_pos': 0.61544406},
#  260: {'vader_neg': 0.0,
#   'vader_neu': 0.833,
#   'vader_pos': 0.167,
#   'vader_compound': 0.8824,
#   'roberta_neg': 0.0016668817,
#   'roberta_neu': 0.052219827,
#   'roberta_pos': 0.94611335},
# ...
#   'vader_compound': 0.8902,
#   'roberta_neg': 0.0036943224,
#   'roberta_neu': 0.020468522,
#   'roberta_pos': 0.9758371},
#  416: {'vader_neg': 0.0,
#   'vader_neu': 0.594,
#   'vader_pos': 0.406,
#   'vader_compound': 0.9612,
#   'roberta_neg': 0.0014899248,
#   'roberta_neu': 0.011894799,
#   'roberta_pos': 0.9866153},
#  417: {'vader_neg': 0.07,
#   'vader_neu': 0.799,
#   'vader_pos': 0.131,
#   'vader_compound': 0.9222,
#   'roberta_neg': 0.03650221,
#   'roberta_neu': 0.10573629,
#   'roberta_pos': 0.8577615},
#  418: {'vader_neg': 0.166,
#   'vader_neu': 0.809,
#   'vader_pos': 0.025,
#   'vader_compound': -0.8957,
#   'roberta_neg': 0.9625668,
#   'roberta_neu': 0.033042952,
#   'roberta_pos': 0.0043901624},
#  419: {'vader_neg': 0.0,
#   'vader_neu': 0.784,
#   'vader_pos': 0.216,
#   'vader_compound': 0.8876,
#   'roberta_neg': 0.08711902,
#   'roberta_neu': 0.2939779,
#   'roberta_pos': 0.6189031},
#  420: {'vader_neg': 0.148,
#   'vader_neu': 0.815,
#   'vader_pos': 0.037,
#   'vader_compound': -0.5983,
#   'roberta_neg': 0.014699123,
#   'roberta_neu': 0.10605639,
#   'roberta_pos': 0.8792445},
#  421: {'vader_neg': 0.035,
#   'vader_neu': 0.754,
#   'vader_pos': 0.211,
#   'vader_compound': 0.9561,
#   'roberta_neg': 0.00460123,
#   'roberta_neu': 0.025528014,
#   'roberta_pos': 0.96987075},
#  422: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.4404,
#   'roberta_neg': 0.25421965,
#   'roberta_neu': 0.5514286,
#   'roberta_pos': 0.19435172},
#  423: {'vader_neg': 0.223,
#   'vader_neu': 0.68,
#   'vader_pos': 0.096,
#   'vader_compound': -0.3314,
#   'roberta_neg': 0.61268747,
#   'roberta_neu': 0.31332767,
#   'roberta_pos': 0.07398493},
#  424: {'vader_neg': 0.055,
#   'vader_neu': 0.687,
#   'vader_pos': 0.258,
#   'vader_compound': 0.9106,
#   'roberta_neg': 0.004854863,
#   'roberta_neu': 0.03652875,
#   'roberta_pos': 0.95861644},
#  425: {'vader_neg': 0.017,
#   'vader_neu': 0.821,
#   'vader_pos': 0.161,
#   'vader_compound': 0.9576,
#   'roberta_neg': 0.006257881,
#   'roberta_neu': 0.034265853,
#   'roberta_pos': 0.9594763},
#  426: {'vader_neg': 0.0,
#   'vader_neu': 0.806,
#   'vader_pos': 0.194,
#   'vader_compound': 0.7717,
#   'roberta_neg': 0.012697511,
#   'roberta_neu': 0.13296168,
#   'roberta_pos': 0.85434085},
#  427: {'vader_neg': 0.029,
#   'vader_neu': 0.817,
#   'vader_pos': 0.154,
#   'vader_compound': 0.7845,
#   'roberta_neg': 0.012627847,
#   'roberta_neu': 0.076257065,
#   'roberta_pos': 0.91111505},
#  428: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.9337,
#   'roberta_neg': 0.0018590481,
#   'roberta_neu': 0.012468765,
#   'roberta_pos': 0.9856721},
#  429: {'vader_neg': 0.0,
#   'vader_neu': 0.739,
#   'vader_pos': 0.261,
#   'vader_compound': 0.9741,
#   'roberta_neg': 0.008164912,
#   'roberta_neu': 0.051790576,
#   'roberta_pos': 0.9400446},
#  430: {'vader_neg': 0.0,
#   'vader_neu': 0.617,
#   'vader_pos': 0.383,
#   'vader_compound': 0.9876,
#   'roberta_neg': 0.0016139905,
#   'roberta_neu': 0.0074673165,
#   'roberta_pos': 0.99091864},
#  431: {'vader_neg': 0.04,
#   'vader_neu': 0.786,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9847,
#   'roberta_neg': 0.006102614,
#   'roberta_neu': 0.026842132,
#   'roberta_pos': 0.9670553},
#  432: {'vader_neg': 0.0,
#   'vader_neu': 0.73,
#   'vader_pos': 0.27,
#   'vader_compound': 0.9516,
#   'roberta_neg': 0.011265251,
#   'roberta_neu': 0.08173895,
#   'roberta_pos': 0.9069958},
#  433: {'vader_neg': 0.083,
#   'vader_neu': 0.751,
#   'vader_pos': 0.166,
#   'vader_compound': 0.8044,
#   'roberta_neg': 0.018771198,
#   'roberta_neu': 0.049867142,
#   'roberta_pos': 0.9313617},
#  434: {'vader_neg': 0.108,
#   'vader_neu': 0.593,
#   'vader_pos': 0.299,
#   'vader_compound': 0.8655,
#   'roberta_neg': 0.059044294,
#   'roberta_neu': 0.07542483,
#   'roberta_pos': 0.8655309},
#  435: {'vader_neg': 0.0,
#   'vader_neu': 0.771,
#   'vader_pos': 0.229,
#   'vader_compound': 0.9179,
#   'roberta_neg': 0.0068401815,
#   'roberta_neu': 0.053331323,
#   'roberta_pos': 0.93982846},
#  436: {'vader_neg': 0.0,
#   'vader_neu': 0.829,
#   'vader_pos': 0.171,
#   'vader_compound': 0.8519,
#   'roberta_neg': 0.0037277292,
#   'roberta_neu': 0.01801925,
#   'roberta_pos': 0.97825307},
#  437: {'vader_neg': 0.0,
#   'vader_neu': 0.926,
#   'vader_pos': 0.074,
#   'vader_compound': 0.7383,
#   'roberta_neg': 0.007436057,
#   'roberta_neu': 0.13899876,
#   'roberta_pos': 0.85356516},
#  438: {'vader_neg': 0.0,
#   'vader_neu': 0.887,
#   'vader_pos': 0.113,
#   'vader_compound': 0.6369,
#   'roberta_neg': 0.0011589363,
#   'roberta_neu': 0.012277905,
#   'roberta_pos': 0.9865631},
#  439: {'vader_neg': 0.0,
#   'vader_neu': 0.728,
#   'vader_pos': 0.272,
#   'vader_compound': 0.87,
#   'roberta_neg': 0.0018007217,
#   'roberta_neu': 0.013664487,
#   'roberta_pos': 0.98453486},
#  440: {'vader_neg': 0.072,
#   'vader_neu': 0.781,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9307,
#   'roberta_neg': 0.19511503,
#   'roberta_neu': 0.4615411,
#   'roberta_pos': 0.34334382},
#  441: {'vader_neg': 0.078,
#   'vader_neu': 0.793,
#   'vader_pos': 0.129,
#   'vader_compound': 0.5176,
#   'roberta_neg': 0.05765979,
#   'roberta_neu': 0.35489178,
#   'roberta_pos': 0.5874485},
#  442: {'vader_neg': 0.054,
#   'vader_neu': 0.69,
#   'vader_pos': 0.257,
#   'vader_compound': 0.9683,
#   'roberta_neg': 0.0018980368,
#   'roberta_neu': 0.008375019,
#   'roberta_pos': 0.98972696},
#  443: {'vader_neg': 0.0,
#   'vader_neu': 0.616,
#   'vader_pos': 0.384,
#   'vader_compound': 0.9603,
#   'roberta_neg': 0.0012334298,
#   'roberta_neu': 0.0070420704,
#   'roberta_pos': 0.99172455},
#  444: {'vader_neg': 0.044,
#   'vader_neu': 0.898,
#   'vader_pos': 0.058,
#   'vader_compound': 0.1882,
#   'roberta_neg': 0.19155568,
#   'roberta_neu': 0.5143032,
#   'roberta_pos': 0.2941411},
#  445: {'vader_neg': 0.055,
#   'vader_neu': 0.873,
#   'vader_pos': 0.072,
#   'vader_compound': 0.0935,
#   'roberta_neg': 0.018945225,
#   'roberta_neu': 0.17616373,
#   'roberta_pos': 0.804891},
#  446: {'vader_neg': 0.077,
#   'vader_neu': 0.78,
#   'vader_pos': 0.143,
#   'vader_compound': 0.3699,
#   'roberta_neg': 0.5097049,
#   'roberta_neu': 0.31241652,
#   'roberta_pos': 0.1778786},
#  447: {'vader_neg': 0.042,
#   'vader_neu': 0.763,
#   'vader_pos': 0.195,
#   'vader_compound': 0.9883,
#   'roberta_neg': 0.013550508,
#   'roberta_neu': 0.09274986,
#   'roberta_pos': 0.89369965},
#  448: {'vader_neg': 0.0,
#   'vader_neu': 0.713,
#   'vader_pos': 0.287,
#   'vader_compound': 0.967,
#   'roberta_neg': 0.002935744,
#   'roberta_neu': 0.01181501,
#   'roberta_pos': 0.9852492},
#  449: {'vader_neg': 0.0,
#   'vader_neu': 0.737,
#   'vader_pos': 0.263,
#   'vader_compound': 0.8531,
#   'roberta_neg': 0.0017834383,
#   'roberta_neu': 0.009716066,
#   'roberta_pos': 0.9885005},
#  450: {'vader_neg': 0.0,
#   'vader_neu': 0.845,
#   'vader_pos': 0.155,
#   'vader_compound': 0.6908,
#   'roberta_neg': 0.0036159423,
#   'roberta_neu': 0.047053874,
#   'roberta_pos': 0.94933015},
#  451: {'vader_neg': 0.034,
#   'vader_neu': 0.743,
#   'vader_pos': 0.223,
#   'vader_compound': 0.9873,
#   'roberta_neg': 0.0053236904,
#   'roberta_neu': 0.040369075,
#   'roberta_pos': 0.95430726},
#  452: {'vader_neg': 0.054,
#   'vader_neu': 0.782,
#   'vader_pos': 0.164,
#   'vader_compound': 0.9337,
#   'roberta_neg': 0.12190913,
#   'roberta_neu': 0.24003704,
#   'roberta_pos': 0.63805383},
#  453: {'vader_neg': 0.0,
#   'vader_neu': 0.5,
#   'vader_pos': 0.5,
#   'vader_compound': 0.943,
#   'roberta_neg': 0.0017866727,
#   'roberta_neu': 0.004914191,
#   'roberta_pos': 0.9932991},
#  454: {'vader_neg': 0.0,
#   'vader_neu': 0.603,
#   'vader_pos': 0.397,
#   'vader_compound': 0.8811,
#   'roberta_neg': 0.0012915955,
#   'roberta_neu': 0.007356497,
#   'roberta_pos': 0.99135196},
#  455: {'vader_neg': 0.0,
#   'vader_neu': 0.699,
#   'vader_pos': 0.301,
#   'vader_compound': 0.9619,
#   'roberta_neg': 0.0015823978,
#   'roberta_neu': 0.014091778,
#   'roberta_pos': 0.9843258},
#  456: {'vader_neg': 0.082,
#   'vader_neu': 0.854,
#   'vader_pos': 0.064,
#   'vader_compound': -0.4854,
#   'roberta_neg': 0.12627171,
#   'roberta_neu': 0.2459167,
#   'roberta_pos': 0.62781155},
#  457: {'vader_neg': 0.0,
#   'vader_neu': 0.684,
#   'vader_pos': 0.316,
#   'vader_compound': 0.926,
#   'roberta_neg': 0.0030426534,
#   'roberta_neu': 0.030558042,
#   'roberta_pos': 0.9663993},
#  458: {'vader_neg': 0.0,
#   'vader_neu': 0.564,
#   'vader_pos': 0.436,
#   'vader_compound': 0.9642,
#   'roberta_neg': 0.0016372128,
#   'roberta_neu': 0.007896161,
#   'roberta_pos': 0.99046665},
#  459: {'vader_neg': 0.045,
#   'vader_neu': 0.717,
#   'vader_pos': 0.239,
#   'vader_compound': 0.8455,
#   'roberta_neg': 0.002773952,
#   'roberta_neu': 0.009467643,
#   'roberta_pos': 0.98775834},
#  460: {'vader_neg': 0.066,
#   'vader_neu': 0.743,
#   'vader_pos': 0.19,
#   'vader_compound': 0.9481,
#   'roberta_neg': 0.0072298073,
#   'roberta_neu': 0.019606508,
#   'roberta_pos': 0.9731637},
#  461: {'vader_neg': 0.08,
#   'vader_neu': 0.821,
#   'vader_pos': 0.099,
#   'vader_compound': 0.4883,
#   'roberta_neg': 0.5174431,
#   'roberta_neu': 0.3589137,
#   'roberta_pos': 0.12364315},
#  462: {'vader_neg': 0.037,
#   'vader_neu': 0.87,
#   'vader_pos': 0.093,
#   'vader_compound': 0.34,
#   'roberta_neg': 0.42455176,
#   'roberta_neu': 0.42806113,
#   'roberta_pos': 0.14738703},
#  463: {'vader_neg': 0.099,
#   'vader_neu': 0.794,
#   'vader_pos': 0.108,
#   'vader_compound': 0.5983,
#   'roberta_neg': 0.14180112,
#   'roberta_neu': 0.2807591,
#   'roberta_pos': 0.57743984},
#  464: {'vader_neg': 0.019,
#   'vader_neu': 0.868,
#   'vader_pos': 0.113,
#   'vader_compound': 0.8443,
#   'roberta_neg': 0.06943116,
#   'roberta_neu': 0.30800313,
#   'roberta_pos': 0.62256575},
#  465: {'vader_neg': 0.0,
#   'vader_neu': 0.838,
#   'vader_pos': 0.162,
#   'vader_compound': 0.7823,
#   'roberta_neg': 0.004316439,
#   'roberta_neu': 0.0119086,
#   'roberta_pos': 0.98377496},
#  466: {'vader_neg': 0.0,
#   'vader_neu': 0.772,
#   'vader_pos': 0.228,
#   'vader_compound': 0.9606,
#   'roberta_neg': 0.0016010238,
#   'roberta_neu': 0.006990748,
#   'roberta_pos': 0.99140817},
#  467: {'vader_neg': 0.009,
#   'vader_neu': 0.845,
#   'vader_pos': 0.147,
#   'vader_compound': 0.9874,
#   'roberta_neg': 0.0069541074,
#   'roberta_neu': 0.11868079,
#   'roberta_pos': 0.8743651},
#  468: {'vader_neg': 0.008,
#   'vader_neu': 0.818,
#   'vader_pos': 0.174,
#   'vader_compound': 0.9926,
#   'roberta_neg': 0.004944496,
#   'roberta_neu': 0.10956257,
#   'roberta_pos': 0.885493},
#  469: {'vader_neg': 0.049,
#   'vader_neu': 0.951,
#   'vader_pos': 0.0,
#   'vader_compound': -0.3595,
#   'roberta_neg': 0.0074558794,
#   'roberta_neu': 0.049894556,
#   'roberta_pos': 0.94264954},
#  470: {'vader_neg': 0.0,
#   'vader_neu': 0.957,
#   'vader_pos': 0.043,
#   'vader_compound': 0.25,
#   'roberta_neg': 0.0024990672,
#   'roberta_neu': 0.02566893,
#   'roberta_pos': 0.971832},
#  471: {'vader_neg': 0.051,
#   'vader_neu': 0.676,
#   'vader_pos': 0.273,
#   'vader_compound': 0.9749,
#   'roberta_neg': 0.03436215,
#   'roberta_neu': 0.14488819,
#   'roberta_pos': 0.82074964},
#  472: {'vader_neg': 0.0,
#   'vader_neu': 0.565,
#   'vader_pos': 0.435,
#   'vader_compound': 0.9649,
#   'roberta_neg': 0.0134301465,
#   'roberta_neu': 0.10987375,
#   'roberta_pos': 0.8766961},
#  473: {'vader_neg': 0.0,
#   'vader_neu': 0.686,
#   'vader_pos': 0.314,
#   'vader_compound': 0.7506,
#   'roberta_neg': 0.0033767172,
#   'roberta_neu': 0.02337383,
#   'roberta_pos': 0.97324944},
#  474: {'vader_neg': 0.013,
#   'vader_neu': 0.75,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9828,
#   'roberta_neg': 0.017603321,
#   'roberta_neu': 0.072812624,
#   'roberta_pos': 0.90958405},
#  475: {'vader_neg': 0.0,
#   'vader_neu': 0.585,
#   'vader_pos': 0.415,
#   'vader_compound': 0.9095,
#   'roberta_neg': 0.0014492891,
#   'roberta_neu': 0.007523307,
#   'roberta_pos': 0.9910274},
#  476: {'vader_neg': 0.066,
#   'vader_neu': 0.614,
#   'vader_pos': 0.32,
#   'vader_compound': 0.9684,
#   'roberta_neg': 0.0035778831,
#   'roberta_neu': 0.011040165,
#   'roberta_pos': 0.98538196},
#  477: {'vader_neg': 0.034,
#   'vader_neu': 0.728,
#   'vader_pos': 0.238,
#   'vader_compound': 0.8555,
#   'roberta_neg': 0.0015812078,
#   'roberta_neu': 0.013900232,
#   'roberta_pos': 0.9845185},
#  478: {'vader_neg': 0.0,
#   'vader_neu': 0.823,
#   'vader_pos': 0.177,
#   'vader_compound': 0.6239,
#   'roberta_neg': 0.021452853,
#   'roberta_neu': 0.07885053,
#   'roberta_pos': 0.8996966},
#  479: {'vader_neg': 0.245,
#   'vader_neu': 0.652,
#   'vader_pos': 0.103,
#   'vader_compound': -0.3855,
#   'roberta_neg': 0.18732335,
#   'roberta_neu': 0.5065774,
#   'roberta_pos': 0.30609924},
#  480: {'vader_neg': 0.0,
#   'vader_neu': 0.435,
#   'vader_pos': 0.565,
#   'vader_compound': 0.9935,
#   'roberta_neg': 0.0023286182,
#   'roberta_neu': 0.013533923,
#   'roberta_pos': 0.98413754},
#  481: {'vader_neg': 0.022,
#   'vader_neu': 0.728,
#   'vader_pos': 0.249,
#   'vader_compound': 0.9451,
#   'roberta_neg': 0.021744134,
#   'roberta_neu': 0.06583724,
#   'roberta_pos': 0.9124186},
#  482: {'vader_neg': 0.0,
#   'vader_neu': 0.605,
#   'vader_pos': 0.395,
#   'vader_compound': 0.9079,
#   'roberta_neg': 0.0013218186,
#   'roberta_neu': 0.009695515,
#   'roberta_pos': 0.9889826},
#  483: {'vader_neg': 0.0,
#   'vader_neu': 0.862,
#   'vader_pos': 0.138,
#   'vader_compound': 0.3384,
#   'roberta_neg': 0.0016637428,
#   'roberta_neu': 0.012073511,
#   'roberta_pos': 0.9862627},
#  484: {'vader_neg': 0.088,
#   'vader_neu': 0.767,
#   'vader_pos': 0.145,
#   'vader_compound': 0.4516,
#   'roberta_neg': 0.8551748,
#   'roberta_neu': 0.12534106,
#   'roberta_pos': 0.019484082},
#  485: {'vader_neg': 0.0,
#   'vader_neu': 0.761,
#   'vader_pos': 0.239,
#   'vader_compound': 0.8547,
#   'roberta_neg': 0.080300614,
#   'roberta_neu': 0.22237761,
#   'roberta_pos': 0.6973218},
#  486: {'vader_neg': 0.0,
#   'vader_neu': 0.818,
#   'vader_pos': 0.182,
#   'vader_compound': 0.9224,
#   'roberta_neg': 0.009655726,
#   'roberta_neu': 0.107732296,
#   'roberta_pos': 0.882612},
#  487: {'vader_neg': 0.0,
#   'vader_neu': 0.909,
#   'vader_pos': 0.091,
#   'vader_compound': 0.296,
#   'roberta_neg': 0.16178483,
#   'roberta_neu': 0.5413801,
#   'roberta_pos': 0.29683504},
#  488: {'vader_neg': 0.179,
#   'vader_neu': 0.707,
#   'vader_pos': 0.114,
#   'vader_compound': -0.3723,
#   'roberta_neg': 0.71046406,
#   'roberta_neu': 0.19951259,
#   'roberta_pos': 0.09002334},
#  489: {'vader_neg': 0.0,
#   'vader_neu': 0.861,
#   'vader_pos': 0.139,
#   'vader_compound': 0.9598,
#   'roberta_neg': 0.10650099,
#   'roberta_neu': 0.32596076,
#   'roberta_pos': 0.56753826},
#  490: {'vader_neg': 0.0,
#   'vader_neu': 0.763,
#   'vader_pos': 0.237,
#   'vader_compound': 0.9788,
#   'roberta_neg': 0.0017469608,
#   'roberta_neu': 0.017913932,
#   'roberta_pos': 0.9803391},
#  491: {'vader_neg': 0.055,
#   'vader_neu': 0.704,
#   'vader_pos': 0.241,
#   'vader_compound': 0.9287,
#   'roberta_neg': 0.6072715,
#   'roberta_neu': 0.28218248,
#   'roberta_pos': 0.110546045},
#  492: {'vader_neg': 0.0,
#   'vader_neu': 0.717,
#   'vader_pos': 0.283,
#   'vader_compound': 0.9367,
#   'roberta_neg': 0.00205126,
#   'roberta_neu': 0.013804731,
#   'roberta_pos': 0.984144},
#  493: {'vader_neg': 0.056,
#   'vader_neu': 0.855,
#   'vader_pos': 0.089,
#   'vader_compound': 0.5976,
#   'roberta_neg': 0.17749985,
#   'roberta_neu': 0.30946016,
#   'roberta_pos': 0.51304},
#  494: {'vader_neg': 0.1,
#   'vader_neu': 0.645,
#   'vader_pos': 0.254,
#   'vader_compound': 0.6486,
#   'roberta_neg': 0.29517776,
#   'roberta_neu': 0.53552145,
#   'roberta_pos': 0.16930076},
#  495: {'vader_neg': 0.0,
#   'vader_neu': 0.788,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9743,
#   'roberta_neg': 0.004486078,
#   'roberta_neu': 0.027288673,
#   'roberta_pos': 0.9682253},
#  496: {'vader_neg': 0.0,
#   'vader_neu': 0.554,
#   'vader_pos': 0.446,
#   'vader_compound': 0.9725,
#   'roberta_neg': 0.0019062854,
#   'roberta_neu': 0.009861645,
#   'roberta_pos': 0.9882321},
#  497: {'vader_neg': 0.059,
#   'vader_neu': 0.799,
#   'vader_pos': 0.142,
#   'vader_compound': 0.7833,
#   'roberta_neg': 0.004415364,
#   'roberta_neu': 0.034215305,
#   'roberta_pos': 0.96136934},
#  498: {'vader_neg': 0.025,
#   'vader_neu': 0.762,
#   'vader_pos': 0.212,
#   'vader_compound': 0.9848,
#   'roberta_neg': 0.0064265328,
#   'roberta_neu': 0.07453738,
#   'roberta_pos': 0.91903603},
#  499: {'vader_neg': 0.041,
#   'vader_neu': 0.904,
#   'vader_pos': 0.055,
#   'vader_compound': 0.128,
#   'roberta_neg': 0.86561406,
#   'roberta_neu': 0.11936596,
#   'roberta_pos': 0.015019883},
#  500: {'vader_neg': 0.0,
#   'vader_neu': 0.678,
#   'vader_pos': 0.322,
#   'vader_compound': 0.9811,
#   'roberta_neg': 0.0024397594,
#   'roberta_neu': 0.011327226,
#   'roberta_pos': 0.986233}}

# %%
results_df = pd.DataFrame(res).T
results_df = results_df.reset_index().rename(columns = {'index': 'Id'})

results_df =results_df.merge(df, how = 'left')

# %% [markdown]
# Comparing the scores between the models

# %%
results_df.columns
results_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098067     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text
# 0  I have bought several of the Vitality canned d...
# 1  Product arrived labeled as Jumbo Salted Peanut...
# 2  This is a confection that has been around a fe...
# 3  If you are looking for the secret ingredient i...
# 4  Great taffy at a great price.  There was a wid...

# %% [markdown]
# Combine and compare, not in the project
# then i did splitting of the reviews.csv into positive and negative csv
# then i i did preprocessing on the positive and negative csv and obtained the wordcloud files
# For accuracy,

# %%
# sns.pairplot(data =results_df, 
#              vars = ['vader_neg', 'vader_neu', 'vader_pos', 'roberta_neg', 'roberta_neu', 'roberta_pos'],
            
#             hue ='Score', 
#              palette = 'tab10')

# plt.show()

# %% [markdown]
# # Finding Roberta Accuracy

# %%
rd = results_df 

rd['sentiment roberta'] = rd['roberta_pos'] - rd['roberta_neg']
# total value range is in -1 to 1 values


sorted_rd = rd.sort_values('sentiment roberta',ascending = False)
pos_rd = sorted_rd[sorted_rd['sentiment roberta']>0.1]
neg_rd = sorted_rd[sorted_rd['sentiment roberta']<-0.1]
neu_rd = sorted_rd[sorted_rd['sentiment roberta']==0]



pos_rd.to_csv('pos_roberta.csv', index = False)
neu_rd.to_csv('nue_roberta.csv', index = False)
neg_rd.to_csv('neg_roberta.csv', index = False)


#there is an extra sentiment so i am removing this now
#sorted_rd = sorted_rd.drop('sentiment', axis = 1)
#sorted_rd.tail()

# %%
from sklearn.metrics import accuracy_score

datarob = sorted_rd


datarob["polarity_rating"] = datarob.apply(lambda row: "negative" if row["sentiment roberta"] < -0.1 else "positive" if row["sentiment roberta"]>0.1 else "neutral", axis = 1)

    
threshold =3                             
datarob["score_rating"] = datarob["Score"].apply(lambda x: "positive" if x >= threshold else "negative") 

     
accuracy = accuracy_score(datarob["score_rating"], datarob["polarity_rating"])
print("Accuracy Roberta:", accuracy)

datarob
# Out:
# Accuracy Roberta: 0.9036144578313253
#       Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 362  365      0.033      0.621      0.346          0.9334     0.001597
# 450  453      0.000      0.500      0.500          0.9430     0.001787
# 153  155      0.000      0.647      0.353          0.9803     0.001630
# 393  396      0.000      0.502      0.498          0.9677     0.001319
# 13    14      0.000      0.355      0.645          0.9466     0.001408
# ..   ...        ...        ...        ...             ...          ...
# 250  253      0.107      0.893      0.000         -0.4767     0.968831
# 379  382      0.318      0.515      0.167         -0.7184     0.972539
# 400  403      0.215      0.697      0.088         -0.6351     0.976329
# 50    51      0.220      0.780      0.000         -0.5448     0.976355
# 255  258      0.105      0.816      0.079         -0.3489     0.978985
#
#      roberta_neu  roberta_pos   ProductId          UserId  \
# 362     0.004811     0.993592  B00437JI8Q  A3UM3M6WSUN5BR
# 450     0.004914     0.993299  B000G6RYNE  A1465JH39KR5O5
# 153     0.005390     0.992980  B000SV90J8  A1CY94Z8YWQV12
# 393     0.006035     0.992647  B001ELL6O8   A72H1W5S6UFMY
# 13      0.005883     0.992709  B001GVISJM  A18ECVX2RJ7HUE
# ..           ...          ...         ...             ...
# 250     0.028154     0.003015  B0002567IW  A1SSKFPX72MSMR
# 379     0.023539     0.003922  B003YXWAF8  A1KQXO716WOOD6
# 400     0.020631     0.003040  B001ELL6O8  A2APBHKZCMD6DO
# 50      0.020687     0.002957  B001EO5QW8  A108P30XVUFKXY
# 255     0.018780     0.002235  B00821UN4M  A332AAPB4P75L4
#
#                      ProfileName  HelpfulnessNumerator  \
# 362                     S. Smith                     1
# 450                       persia                     0
# 153             Karas M. Stewart                     1
# 393    King of Breakfasts "King"                     1
# 13               willie "roadie"                     2
# ..                           ...                   ...
# 250  Janna M. Sicard "missjanna"                     0
# 379               Allison Beegle                     7
# 400                            X                     0
# 50                     Roberto A                     0
# 255              Heather Crimson                     2
#
#      HelpfulnessDenominator  Score        Time                 Summary  \
# 362                       1      5  1316217600                Best Bar
# 450                       0      5  1287360000         Best deal ever!
# 153                       1      5  1267401600                  JELL-O
# 393                       1      5  1278460800  A Great All Around Mix
# 13                        2      4  1288915200       fresh and greasy!
# ..                      ...    ...         ...                     ...
# 250                       0      1  1344556800             Sad outcome
# 379                      13      1  1309305600          Waste of money
# 400                       6      1  1207353600                   Awful
# 50                        7      1  1203379200           Don't like it
# 255                       2      1  1348099200    Reeks like chemicals
#
#                                                   Text  sentiment roberta  \
# 362  These are my favorite bars ever. The combo of ...           0.991994
# 450  This was the best deal ever. The delivery was ...           0.991512
# 153  AWESOME!!! such a yummy flavor I got it as a h...           0.991350
# 393  I appreciate the fact that I can buy this prod...           0.991328
# 13   good flavor! these came securely packed... the...           0.991301
# ..                                                 ...                ...
# 250  Five minutes in, one tentacle was bitten off, ...          -0.965815
# 379  These condiments are overpriced and terrible. ...          -0.968618
# 400  Just awful!  I thought food was supposed to ta...          -0.973288
# 50   This oatmeal is not good. Its mushy, soft, I d...          -0.973398
# 255  I so wish I would have read this review before...          -0.976749
#
#     polarity_rating score_rating
# 362        positive     positive
# 450        positive     positive
# 153        positive     positive
# 393        positive     positive
# 13         positive     positive
# ..              ...          ...
# 250        negative     negative
# 379        negative     negative
# 400        negative     negative
# 50         negative     negative
# 255        negative     negative
#
# [498 rows x 20 columns]

# %% [markdown]
# # Finding WordClouds for ROBERTA

# %% [markdown]
# POSITIVE WORDCLOUD

# %%
results_df.head()
# Out:
#    Id  vader_neg  vader_neu  vader_pos  vader_compound  roberta_neg  \
# 0   1      0.000      0.695      0.305          0.9441     0.009624
# 1   2      0.138      0.862      0.000         -0.5664     0.508986
# 2   3      0.091      0.754      0.155          0.8265     0.003229
# 3   4      0.000      1.000      0.000          0.0000     0.002295
# 4   5      0.000      0.552      0.448          0.9468     0.001635
#
#    roberta_neu  roberta_pos   ProductId          UserId  \
# 0     0.049980     0.940395  B001E4KFG0  A3SGXH7AUHU8GW
# 1     0.452414     0.038600  B00813GRG4  A1D87F6ZCVE5NK
# 2     0.098067     0.898704  B000LQOCH0   ABXLMWJIXXAIN
# 3     0.090219     0.907486  B000UA0QIQ  A395BORC6FGVXV
# 4     0.010302     0.988063  B006K2ZZ7K  A1UQRSCLF8GW1T
#
#                        ProfileName  HelpfulnessNumerator  \
# 0                       delmartian                     1
# 1                           dll pa                     0
# 2  Natalia Corres "Natalia Corres"                     1
# 3                             Karl                     3
# 4    Michael D. Bigham "M. Wassir"                     0
#
#    HelpfulnessDenominator  Score        Time                Summary  \
# 0                       1      5  1303862400  Good Quality Dog Food
# 1                       0      1  1346976000      Not as Advertised
# 2                       1      4  1219017600  "Delight" says it all
# 3                       3      2  1307923200         Cough Medicine
# 4                       0      5  1350777600            Great taffy
#
#                                                 Text  sentiment roberta
# 0  I have bought several of the Vitality canned d...           0.930771
# 1  Product arrived labeled as Jumbo Salted Peanut...          -0.470386
# 2  This is a confection that has been around a fe...           0.895475
# 3  If you are looking for the secret ingredient i...           0.905191
# 4  Great taffy at a great price.  There was a wid...           0.986428

# %%
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
import sys, os
os.chdir(sys.path[0])

# Read CSV file into a pandas DataFrame
df2 = pd.read_csv('pos_roberta.csv')

# Extract text from a specific column
pos_rob_text1 = df2['Text'].to_string(index=False)

# Save the text to a text file
with open('pos_rob_text1.txt', 'w', encoding='utf-8') as file:
    file.write(pos_rob_text1)
    
    
text1 = open('pos_rob_text1.txt', mode = 'r', encoding = 'utf-8').read()
stopwords = set(stopwords.words('english'))

wc = WordCloud(
        background_color = 'white',
        stopwords= stopwords,
        height = 600,
        width = 400)

wc.generate(text1)
wc.to_file('Positive_ROBERTA.png')

# %%
from IPython.display import Image
Image(filename = "Positive_ROBERTA.png", width = 500, height =1000)

# %% [markdown]
# NEGATIVE WORDCLOUD

# %%
from nltk.corpus import stopwords
import matplotlib.pyplot as plt
from wordcloud import WordCloud,STOPWORDS
import sys, os
os.chdir(sys.path[0])

# Read CSV file into a pandas DataFrame
df3 = pd.read_csv('neg_roberta.csv')

# Extract text from a specific column
neg_rob_text1 = df3['Text'].to_string(index=False)

# Save the text to a text file
with open('neg_rob_text1.txt', 'w', encoding='utf-8') as file:
    file.write(neg_rob_text1)
    
    
text2 = open('neg_rob_text1.txt', mode = 'r', encoding = 'utf-8').read()
stopwords = set(stopwords.words('english'))

wc = WordCloud(
        background_color = 'white',
        stopwords= stopwords,
        height = 600,
        width = 400)

wc.generate(text2)
wc.to_file('Negative_ROBERTA.png')

#displaying the word cloud which is generated in the above code
Image(filename = "Negative_ROBERTA.png", width = 500, height =1000)

# %% [markdown]
# # Finding Wordclouds using VADER
